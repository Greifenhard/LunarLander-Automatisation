# %% [markdown]
# # Evaluierung eines PID-gesteuerten Agenten in der LunarLander-v3-Umgebung

# %% [markdown]
# @Autor Michael Greif

# %% [markdown]
# In dieser Demonstration wird die Leistung eines Agenten evaluiert, der mittels PID-Reglern in der LunarLander-v3-Umgebung von OpenAI Gym gesteuert wird. Die Aufgabe des Agenten besteht darin, ein Raumschiff sicher auf einer Plattform zu landen, wobei er drei wesentliche Dimensionen steuern muss:
#
# 1. **Vertikale Position**: Das Raumschiff soll sanft auf der Plattform landen.
# 2. **Horizontale Position**: Das Raumschiff soll über der Plattform zentriert bleiben.
# 3. **Winkel**: Das Raumschiff soll in einer aufrechten Position ohne Neigung landen.
#
# Für jede dieser Dimensionen wurde ein separater PID-Regler implementiert, um präzise Steuerbefehle basierend auf dem aktuellen Zustand des Raumschiffs zu generieren. Diese Regler helfen dabei, die Abweichungen vom gewünschten Zustand zu minimieren.
#
# Die Simulation wird über eine Reihe von Episoden durchgeführt, um die Effizienz dieser Steuerstrategie zu analysieren. Am Ende jeder Episode werden die Gesamtrewards und die Landungspunkte des Raumschiffs ausgegeben. Darüber hinaus wird eine statistische Auswertung über mehrere Episoden gegeben, um die durchschnittliche Punktezahl und die durchschnittliche Landungsgenauigkeit zu berechnen.

# %% [markdown]
# # Verwendete Bibliotheken

# %% [markdown]
# Bibliotheksreferenzen
# - OpenAI Gymnasium: https://gymnasium.farama.org/
# - NumPy: https://numpy.org/
# - Matplotlib: https://matplotlib.org/

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # PID Controller Class

# %% [markdown]
# Der PID-Controller im folgenden Code ist eine Implementierung eines Proportional-Integral-Derivative (PID) Reglers, der in Steuerungssystemen weit verbreitet ist. Dieser Regler zielt darauf ab, eine dynamische Prozesssteuerung zu ermöglichen, indem er kontinuierlich die Differenz (Fehler) zwischen einem gewünschten Sollwert und einem aktuellen Istwert analysiert und darauf reagiert. Der PID-Regler beeinflusst den Steuerungsoutput durch drei
#
# **Kernkomponenten**:
#
# - **Proportionaler Anteil (Kp)**: Dieser Teil des Reglers reagiert direkt proportional zum aktuellen Fehlerwert. Er veranlasst umso stärkere Anpassungen, je weiter der Istwert vom Sollwert abweicht. Ein gut abgestimmter Kp-Wert hilft, schnelle Korrekturen vorzunehmen, kann aber auch zu Instabilitäten führen, wenn er zu hoch ist.
#
# - **Integraler Anteil (Ki)**: Der Integralaspekt adressiert die Summe der vergangenen Fehler über die Zeit. Er korrigiert stetige Abweichungen, die sich im Zeitverlauf aufsummieren, und sorgt dafür, dass der Regler keine dauerhafte Diskrepanz zwischen Soll- und Istwert besitzt.
#
# - **Derivativer Anteil (Kd)**: Dieser Bestandteil gibt Aufschluss über die Geschwindigkeit der Fehlerveränderung und ist entscheidend zur Dämpfung des Systems. Er reduziert die Reaktion auf große Fehler, wenn der Istwert schnell auf den Sollwert zusteuert, und verhindert Überschwinger.
#
# Die Methode `update` des PID-Controllers berechnet den Steuerungsoutput basierend auf den Werten dieser drei Parameter und dem gegebenen Fehler. Die Methode `reset` dient zur Initialisierung der vorhergehenden Fehler und der Integralsumme, falls ein Neustart oder ein erneuter Steuerprozess notwendig ist.

# %%
class PIDController:
    def __init__(self, Kp, Ki, Kd):
        # Initialisiert den PID-Controller mit den gegebenen Koeffizienten
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.prev_error = 0
        self.integral = 0

    def reset(self):
        # Setzt die gespeicherten Zustände zurück
        self.prev_error = 0
        self.integral = 0

    def update(self, error, dt):
        # Berechnet den Ausgang des PID-Reglers auf Basis des aktuellen Fehlers
        self.integral += error * dt
        derivative = (error - self.prev_error) / dt
        output = self.Kp * error + self.Ki * self.integral + self.Kd * derivative
        self.prev_error = error
        return output

# %% [markdown]
# # Funktion zum Testen der Controller

# %% [markdown]
# Zu Beginn wird die Umgebung initialisiert und drei PID-Regler werden mit spezifischen Koeffizienten für proportionale, integrale und differentiale Anteile konfiguriert. Diese Regler steuern jeweils die vertikale Bewegung, die horizontale Bewegung und den Neigungswinkel des Raumschiffs.
#
# Die Simulation läuft über mehrere Episoden. In jeder Episode startet das Raumschiff in einem zufälligen Zustand, und die Regler werden zurückgesetzt, um Änderungen im Steuerungsverhalten zwischen den Episoden zu verhindern. Innerhalb jeder Episode berechnet der Code kontinuierlich die Differenz (Fehler) zwischen dem aktuellen und dem gewünschten Zustand des Raumschiffs. Anhand dieser Fehler bestimmen die PID-Regler entsprechende Steuerungsaktionen.
#
# Der Code umfasst eine Schleife, die bis zum Abschluss jeder Episode läuft. Während dieser Schleife werden die Steuerbefehle basierend auf den berechneten Fehlern aktualisiert, und die resultierenden Aktionen werden auf die Umgebung angewendet. Jede Aktion beeinflusst den Zustand des Raumschiffs und generiert eine Belohnung, die zur Gesamtbelohnung der Episode addiert wird. Wenn das Raumschiff sicher gelandet ist, wird die Episode beendet. Am Ende jeder Episode werden die erzielten Ergebnisse ausgegeben.
#
# Zusätzlich wird ein Überblick über die Leistung in allen durchgeführten Episoden gegeben. Die durchschnittlichen Belohnungen und die Präzision der Landungen werden ausgewertet, um die Effektivität der verwendeten PID-Regler zu beurteilen.

# %%
def evaluate_pid(n_episodes=5, verbose=0, render_mode=None):
    """
    Evaluierung eines PID-gesteuerten Agenten in der LunarLander-v3-Umgebung für eine bestimmte Anzahl von Episoden.

    :param n_episodes: Anzahl der Episoden, die ausgeführt werden sollen (Standardwert ist 5).
    :param verbose: Grad der Detailtiefe für Debug-Ausgaben (Standardwert ist 0, was keine Debug-Ausgabe bedeutet).
    :param render_mode: Modus zum Rendern der Umgebung (Standard ist None, was kein Rendering bedeutet).

    Die Funktion verwendet drei separate PID-Regler zur Steuerung der vertikalen Position, horizontalen Position und des Winkels des Landers. 
    Sie berechnet die Fehler zwischen dem aktuellen und dem gewünschten Zustand, aktualisiert die Aktionen über die PID-Regler und wendet 
    Aktionen auf die Umgebung an. Ziel jeder Episode ist es, das Raumschiff sicher auf der Plattform zu landen und die Geschwindigkeit 
    bei der Landung zu minimieren.
    """
    # Erstelle die Gym-Umgebung mit einer spezifischen Gravitätseinstellung
    env = gym.make("LunarLander-v3", gravity=-10.0, render_mode=render_mode)
    
    # Initialisiere PID-Regler für die vertikale, horizontale Steuerung und den Winkel
    vertical_pid = PIDController(Kp=4.0, Ki=0.5, Kd=1.0)
    horizontal_pid = PIDController(Kp=2.0, Ki=2.0, Kd=0.5)
    angle_pid = PIDController(Kp=4.0, Ki=2.0, Kd=0.3)
    
    total_rewards = []  # Liste zur Speicherung der Gesamtreward pro Episode
    x_cords = []          # Liste zur Speicherung der finalen x-Koordinate der Landung pro Episode

    # Schleife durch jede Episode
    for episode in range(n_episodes):
        state, _ = env.reset()  # Setze die Umgebung für eine neue Episode zurück
        vertical_pid.reset()    # Setze den vertikalen PID-Regler zurück
        horizontal_pid.reset()  # Setze den horizontalen PID-Regler zurück
        angle_pid.reset()       # Setze den Winkel-PID-Regler zurück
        total_reward = 0        # Akkumulator für den Gesamtreward
        done = False            # Flag zur Anzeige des Endes der Episode
        
        # Schleife, bis die Episode beendet ist
        while not done:
            # Entpacke den aktuellen Zustand
            coord_x, coord_y, velocity_x, velocity_y, angle, velocity_angle, left_foot, right_food = state
            
            # Zielzustände für die Steuerung (Sollwerte)
            target_y = 0.0
            target_x = 0.0
            target_angle = 0.0

            # Berechne die Fehler für jede Steuerungsdimension
            y_error = target_y - coord_y - velocity_y * 2
            x_error = target_x + coord_x + velocity_x * 2
            angle_error = target_angle - angle - velocity_angle
            
            # Zeitschritt für die PID-Aktualisierung
            dt = 1.0 / 50.0 

            # Aktualisiere die PID-Regler und erhalte die Steueraktionen
            y_action = vertical_pid.update(y_error, dt)
            x_action = horizontal_pid.update(x_error, dt)
            theta_action = angle_pid.update(angle_error, dt)
            
            if verbose:
                # Debug-Informationen ausgeben, wenn Verbosität aktiviert ist
                print("y: ", coord_y, "v: ", velocity_y, end=" ")
                print("Fehler: ", y_error, "Output: ", y_action)
                print("x: ", coord_x, "v: ", velocity_x, end=" ")
                print("Fehler: ", x_error, "Output: ", x_action)
                print()
            
            # Bestimme die Aktionen basierend auf den Steuerergebnissen
            vertical_action = 2 if y_action > 0 else 0
            horizontal_action = 1 if x_action > 0 else 3
            angle_action = 1 if theta_action > 0 else 3

            # Wähle die endgültige Aktion
            action = vertical_action
            if vertical_action == 0:
                action = horizontal_action if abs(x_action) > abs(theta_action) else angle_action

            # Wende die ausgewählte Aktion auf die Umgebung an
            state, reward, done, _, _ = env.step(action)
            if left_foot and right_food and abs(velocity_y) < 0.005:
                done = True  # Beende die Episode, wenn das Raumschiff erfolgreich landet
            total_reward += reward  # Summiere die Belohnung auf
        
        # Speichere die Ergebnisse der Episode
        x_cords.append(abs(coord_x))
        total_rewards.append(total_reward)
        
        # Episode-Zusammenfassung ausgeben
        print(f"Episode {episode + 1}: {total_reward}")
        print(f"Landung auf ({coord_x:.2f},{coord_y:.2f}) mit Geschwindigkeit = {velocity_y:.2f}")
        print()
    
    env.close()  # Schließe die Umgebung, sobald alle Episoden abgeschlossen sind
    
    # Endergebnisse ausgeben
    print(f"Durchschnittliche Punktzahl über {episode + 1} Episoden: {np.mean(total_rewards)}")
    print(f"Durchschnittliche Entfernung zu x=0.00 über {episode + 1} Episoden: {abs(np.mean(x_cords)):.3f}")
    
    return total_rewards, x_cords

# %% [markdown]
# # Testing

# %% [markdown]
# Die Funktion `evaluate_pid` wird mit `n_episodes=1000` aufgerufen, um den PID-gesteuerten Agenten in der "LunarLander-v3"-Umgebung über 1000 Episoden auszuwerten. Dabei wird das Verhalten des Raumschiffs gesteuert, um es sicher auf einer Plattform zu landen. Die Funktion nutzt drei PID-Regler, um die vertikale und horizontale Bewegung sowie die Neigung des Raumschiffs zu kontrollieren. In jeder Episode wird der aktuelle Zustand des Raumschiffs kontinuierlich mit dem Zielzustand verglichen, um entsprechende Steuerbefehle zu berechnen und anzuwenden. Nach jeder Episode werden die Gesamtbelohnungen und Landungspräzisionen festgehalten, um die mittlere Leistung und Landungsgenauigkeit über alle 1000 Episoden hinweg zu bewerten. Dies ermöglicht eine umfassende Analyse der Effektivität und Anpassung der PID-Regler.

# %%
total_rewards, x_cords = evaluate_pid(n_episodes=1000)
# Out:
# Episode 1: 194.31720492616202
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 2: 167.02605459737055
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 3: 141.81321375044652
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 4: 147.17097705634043
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 5: 163.65327966855983
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 6: 172.78529859930168
# Landung auf (0.06,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 7: 150.7669583188264
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 8: 184.19825301188905
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 9: 121.17852117192291
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 10: 170.65800853971479
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 11: 174.97477241334704
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 12: 134.14842318675824
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 13: 160.24884253306473
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 14: 148.27675403226647
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 15: 182.08285027874186
# Landung auf (0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 16: 131.17617789026446
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 17: 166.40201637782982
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 18: 173.13098940999672
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 19: 177.22163202612745
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 20: 191.53942145256875
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 21: 169.09558697320242
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 22: 139.06362974101788
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 23: 163.0384398736992
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 24: 170.92629554905952
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 25: 181.49509468518772
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 26: 179.01482182179805
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 27: 153.7897180074913
# Landung auf (-0.03,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 28: 177.65249100818647
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 29: 158.57098472795738
# Landung auf (0.09,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 30: 186.1798888776388
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 31: 138.58647231349488
# Landung auf (-0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 32: 170.29882704122718
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 33: 171.6157425127588
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 34: 183.12936087339983
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 35: 144.81233922227483
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 36: 174.10522255485134
# Landung auf (-0.03,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 37: 185.95675426389118
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 38: 170.67591115695845
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 39: 137.64079839635096
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 40: 162.45281095055827
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 41: 152.980663695896
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 42: 146.52039432665805
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 43: 186.1270020761933
# Landung auf (0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 44: 153.31875955207192
# Landung auf (-0.03,0.00) mit Geschwindigkeit = 0.00
#
# Episode 45: 188.25209760643583
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 46: 175.89405811618425
# Landung auf (-0.03,0.00) mit Geschwindigkeit = -0.00
#
# Episode 47: 182.9263740271826
# Landung auf (0.09,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 48: 143.25580546374337
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 49: 151.22684043719863
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 50: 147.09123991257917
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 51: 185.6905833667344
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 52: 136.48900484404834
# Landung auf (-0.00,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 53: 130.05420855576227
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 54: 168.41395095086017
# Landung auf (0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 55: 164.24613641331845
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 56: 192.84707635057003
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 57: 136.80817876414335
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 58: 145.93843961739924
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 59: 188.08313269613063
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 60: 128.0570651863166
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 61: 149.49796598094926
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 62: 171.81848556250017
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 63: 166.46040293230402
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 64: 175.6382174656433
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 65: 172.95644180726663
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 66: 158.64584691863496
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 67: 156.32991991817175
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 68: 143.21134091008392
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 69: 185.15516821145934
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 70: 149.7186594506562
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 71: 142.79791644184886
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 72: 115.99844628306742
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 73: 186.99209389333677
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 74: 160.28866901800268
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 75: 176.4408910574848
# Landung auf (-0.01,0.00) mit Geschwindigkeit = -0.00
#
# Episode 76: 180.37398898256185
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 77: -385.71380975479644
# Landung auf (0.97,0.17) mit Geschwindigkeit = 0.04
#
# Episode 78: 184.33782503941273
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 79: 154.23707763465575
# Landung auf (-0.04,0.00) mit Geschwindigkeit = 0.00
#
# Episode 80: 143.21280216473653
# Landung auf (0.00,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 81: 175.75260487067666
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 82: -207.18944165072259
# Landung auf (0.93,0.02) mit Geschwindigkeit = -0.22
#
# Episode 83: 139.96780664102747
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 84: 161.4383565686536
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 85: 192.44146122334266
# Landung auf (0.01,0.00) mit Geschwindigkeit = -0.00
#
# Episode 86: -264.8080492896763
# Landung auf (0.03,0.02) mit Geschwindigkeit = -0.47
#
# Episode 87: 147.91352265616953
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 88: 163.5778095475764
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 89: 134.08863386935607
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 90: 187.51523553822588
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 91: 125.9749835225264
# Landung auf (0.23,0.04) mit Geschwindigkeit = 0.00
#
# Episode 92: 189.00135283369357
# Landung auf (0.09,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 93: 162.03822850760372
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 94: 146.66615592503447
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 95: 176.33706473367806
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 96: 182.4206083149331
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 97: 145.25126629365585
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 98: 193.55061882687744
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 99: 166.85617985450975
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 100: 184.36682284859376
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 101: 183.19204314831342
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 102: 156.95587447809342
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 103: 154.60118031716087
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 104: 129.37349384260722
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 105: 179.67586918080653
# Landung auf (0.05,0.00) mit Geschwindigkeit = 0.00
#
# Episode 106: 173.68446004364887
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 107: 171.29400672563455
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 108: 161.37197811442954
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 109: 151.1182097057206
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 110: 168.61309500573051
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 111: 157.719705611266
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 112: 127.37219930944457
# Landung auf (0.00,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 113: 148.59553773433177
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 114: 174.02439483368622
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 115: 142.77372000095235
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 116: 128.5114678909203
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 117: 191.55560078716843
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 118: 191.6346346765834
# Landung auf (0.08,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 119: 135.8588894888705
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 120: -105.68508147311839
# Landung auf (-0.95,0.00) mit Geschwindigkeit = 0.04
#
# Episode 121: 134.04436870288495
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 122: 138.62420766568232
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 123: 150.81867292939646
# Landung auf (0.05,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 124: 167.5087942790244
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 125: -264.9666923969278
# Landung auf (-0.06,0.02) mit Geschwindigkeit = -0.49
#
# Episode 126: 171.35887420381653
# Landung auf (-0.08,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 127: 152.79660735569615
# Landung auf (0.05,0.00) mit Geschwindigkeit = -0.00
#
# Episode 128: 154.86570336037505
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 129: 192.72950843084655
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 130: 166.19369536587936
# Landung auf (0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 131: -491.7485952459465
# Landung auf (0.96,-0.00) mit Geschwindigkeit = -0.41
#
# Episode 132: 123.51249671493326
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 133: 153.85720308389304
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 134: 154.44240655260725
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 135: 159.64086057146287
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 136: 143.93226263455054
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 137: 159.32026348557915
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 138: 145.0164292690196
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 139: 167.23722118385885
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 140: 181.5865924264426
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 141: -296.0918410816057
# Landung auf (-0.22,0.04) mit Geschwindigkeit = -0.29
#
# Episode 142: 146.50481965132747
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 143: 173.11698933809458
# Landung auf (-0.09,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 144: 159.73995837180107
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 145: 173.87048460342723
# Landung auf (0.05,0.00) mit Geschwindigkeit = -0.00
#
# Episode 146: 173.55363111852813
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 147: 162.78615228158412
# Landung auf (0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 148: 179.25696909535205
# Landung auf (-0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 149: 188.12701911920226
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 150: 184.19876024854105
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 151: 157.82896925599073
# Landung auf (-0.00,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 152: 147.51155702375604
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 153: 146.13219777781478
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 154: 162.9498755659926
# Landung auf (-0.04,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 155: 166.19787271719352
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 156: 174.46187370897778
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 157: 151.63356224454867
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 158: -378.01229037671874
# Landung auf (0.99,0.19) mit Geschwindigkeit = -0.39
#
# Episode 159: 195.439593451517
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 160: 159.98615493012105
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 161: 155.24314278468714
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 162: 194.96627264041283
# Landung auf (0.07,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 163: 138.4187305268696
# Landung auf (-0.16,0.01) mit Geschwindigkeit = -0.00
#
# Episode 164: 167.16825491477772
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 165: 172.90384534880872
# Landung auf (0.06,0.00) mit Geschwindigkeit = 0.00
#
# Episode 166: 144.55973250065037
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 167: 198.69985831245103
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 168: -432.9852462791159
# Landung auf (0.71,-0.07) mit Geschwindigkeit = -0.72
#
# Episode 169: 165.74382863796214
# Landung auf (0.10,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 170: 117.94609022385497
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 171: 163.75115308125103
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 172: 173.4784745377259
# Landung auf (-0.11,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 173: 128.355914292516
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 174: 163.92433725423132
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 175: 170.780367119178
# Landung auf (-0.06,0.00) mit Geschwindigkeit = -0.00
#
# Episode 176: 165.70245943872095
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 177: -240.10168921682774
# Landung auf (0.07,0.01) mit Geschwindigkeit = -0.72
#
# Episode 178: 200.49179776104003
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 179: 164.35586902036383
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 180: 161.24163995996878
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 181: 157.72632133038047
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 182: 166.35262191231772
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 183: 160.71893355434452
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 184: -274.30051974598155
# Landung auf (-0.37,-0.07) mit Geschwindigkeit = -0.53
#
# Episode 185: 173.28748963869103
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 186: 187.16887537193375
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 187: -388.46585716483565
# Landung auf (0.33,0.04) mit Geschwindigkeit = -0.64
#
# Episode 188: 169.90728465071612
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 189: -316.27050401002975
# Landung auf (0.39,-0.04) mit Geschwindigkeit = -0.75
#
# Episode 190: 167.02938660632935
# Landung auf (0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 191: 155.85917474063132
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 192: 171.2649017850694
# Landung auf (-0.03,0.00) mit Geschwindigkeit = -0.00
#
# Episode 193: 166.30661186755358
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 194: 174.39321906043764
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 195: 175.6732613712926
# Landung auf (0.03,0.00) mit Geschwindigkeit = 0.00
#
# Episode 196: 178.86881632127893
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 197: 188.246385004563
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 198: 143.7693999979403
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 199: 165.9436199797432
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 200: 178.39477564071515
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 201: 178.0837772363457
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 202: 179.03066359042495
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 203: 143.6691675621156
# Landung auf (0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 204: 177.00889488074384
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 205: 177.5942929711524
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 206: 171.93823298913574
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 207: 168.4729464297935
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 208: 173.58869770642588
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 209: 156.4607555533828
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 210: 190.27412754414513
# Landung auf (0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 211: 160.84645609806725
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 212: 184.98001691526198
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 213: 170.0510721552405
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 214: 168.3615480498987
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 215: 162.6245718081216
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 216: 186.2582541069694
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 217: 163.09835020149777
# Landung auf (0.03,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 218: 143.30180372919364
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 219: 172.0025119265182
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 220: 134.4643104550485
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 221: 124.36599610426171
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 222: 185.4851085388153
# Landung auf (0.10,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 223: 165.57341091374738
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 224: 137.87386019852258
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 225: 134.00507480750235
# Landung auf (-0.07,0.00) mit Geschwindigkeit = -0.00
#
# Episode 226: 144.65842874004986
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 227: 161.02549881273055
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 228: 172.36554204140197
# Landung auf (0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 229: 198.7859823075771
# Landung auf (0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 230: 143.19022417579762
# Landung auf (0.01,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 231: 170.53294186580308
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 232: 144.81322057913866
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 233: 180.45644252093342
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 234: 133.05584227069895
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 235: 175.12382687363294
# Landung auf (-0.08,0.00) mit Geschwindigkeit = 0.00
#
# Episode 236: 182.46623159096237
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 237: 177.96079724090276
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 238: 156.3451846081172
# Landung auf (0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 239: 135.49461610498543
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 240: -405.13399198092424
# Landung auf (-0.12,0.01) mit Geschwindigkeit = -0.41
#
# Episode 241: 136.35229999967893
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 242: 161.5415756801308
# Landung auf (0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 243: 167.13436344471538
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 244: 163.39661524469435
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 245: 143.3251432155604
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 246: 181.58648126646557
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 247: 175.63733222336091
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 248: 171.87445690834224
# Landung auf (-0.08,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 249: 186.21129594971697
# Landung auf (-0.00,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 250: 165.43234457770686
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 251: 152.53264551750928
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 252: 168.0857399417782
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 253: 186.37881530044936
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 254: 163.42853472689305
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 255: 161.87444479300973
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 256: 124.33375294783114
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 257: 183.67747114475344
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 258: 136.35143231731126
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 259: 156.82307549775007
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 260: 142.20257051380844
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 261: 135.80683467313185
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 262: 152.92822004556544
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 263: 156.25697466339153
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 264: 181.10582820909013
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 265: 144.884516148742
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 266: 150.16149379714176
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 267: 181.88014961265026
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 268: 195.42787005935435
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 269: 111.51793388387874
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 270: 128.0882122623405
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 271: 121.47922208451563
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 272: 143.13151381434065
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 273: 140.77698612764505
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 274: 165.93178156781127
# Landung auf (0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 275: 173.53993407375353
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 276: 182.16953716104481
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 277: 184.6708629324211
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 278: 169.64026677642343
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 279: 138.79182295364072
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 280: 183.46926737224098
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 281: 173.64116045401389
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 282: 179.69221366907453
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 283: 165.80447449170893
# Landung auf (-0.04,0.00) mit Geschwindigkeit = -0.00
#
# Episode 284: 199.19272947577207
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 285: 172.63330275511157
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 286: 162.10175744028277
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 287: 186.7971151773243
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 288: 143.1779049385455
# Landung auf (0.02,0.00) mit Geschwindigkeit = -0.00
#
# Episode 289: 170.0124075372217
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 290: 125.7547484082859
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 291: 146.77950439688522
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 292: 124.7864244082595
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 293: 186.54910663601743
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 294: 164.71928662578736
# Landung auf (0.01,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 295: 172.80876882441132
# Landung auf (-0.03,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 296: 164.19017637811697
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 297: 179.7969335812649
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 298: 162.35095893348105
# Landung auf (0.08,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 299: 148.79771061242312
# Landung auf (0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 300: 121.4338420542151
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 301: 159.171361195777
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 302: 163.33406573296492
# Landung auf (-0.02,0.00) mit Geschwindigkeit = -0.00
#
# Episode 303: 174.48373332104794
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 304: 172.90169318597412
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 305: 153.78118396272623
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 306: 155.8470887690567
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 307: 136.45009051231705
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 308: 175.5432254059428
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 309: 164.67614623800475
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 310: 172.55893573773596
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 311: 169.52387963087938
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 312: 180.8508946342153
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 313: 178.000463812055
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 314: 177.37784946255874
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 315: 183.41468415482066
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 316: 151.3228655424182
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 317: 171.96056919424086
# Landung auf (0.07,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 318: 205.23445321614685
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 319: 150.46883474562816
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 320: 168.9963077346127
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 321: 161.48157694222883
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 322: 190.40517374591903
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 323: 138.48653992796545
# Landung auf (0.37,0.09) mit Geschwindigkeit = -0.00
#
# Episode 324: 185.51533072737786
# Landung auf (0.05,0.00) mit Geschwindigkeit = -0.00
#
# Episode 325: 136.9579251992245
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 326: 159.04979409419735
# Landung auf (0.16,0.02) mit Geschwindigkeit = -0.00
#
# Episode 327: 171.66201338056743
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 328: 135.7461271516188
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 329: 130.5975926766246
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 330: 178.11949268012586
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 331: 146.46878750446194
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 332: 184.18325540800836
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 333: 174.40841477638452
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 334: 158.8708427341493
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 335: 162.0198588251051
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 336: 169.94275114771685
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 337: 156.8990072994788
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 338: 155.39695947530703
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 339: -217.62065662029113
# Landung auf (0.33,-0.06) mit Geschwindigkeit = -0.14
#
# Episode 340: 157.6564488624839
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 341: 180.2481671404783
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 342: 174.17235031004915
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 343: 183.17591892201094
# Landung auf (0.09,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 344: 136.3163254983472
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 345: 154.9994880262398
# Landung auf (0.15,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 346: 162.11062657991354
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 347: 185.11171072731975
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 348: 177.4847037513288
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 349: 166.92494446155786
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 350: 147.37015762704863
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 351: 133.28177978136517
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 352: 168.5393303663674
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 353: 180.2688328766254
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 354: 162.3334553098368
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 355: 169.88766500778164
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 356: 171.04270147042615
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 357: 182.06597207308207
# Landung auf (-0.07,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 358: 170.37651878929674
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 359: 138.0632705468941
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 360: 159.3731837987567
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 361: 171.91106087781768
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 362: 165.4225582999113
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 363: 176.54954891268133
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 364: 179.39326786142362
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 365: 156.92728977892412
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 366: 192.92117325686152
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 367: 188.7283719355576
# Landung auf (0.09,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 368: 172.55104460943897
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 369: -261.5623726453392
# Landung auf (0.68,-0.03) mit Geschwindigkeit = -0.55
#
# Episode 370: 136.87248050481193
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 371: 173.18029162269417
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 372: 148.70184704199215
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 373: 171.23938068872474
# Landung auf (-0.09,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 374: 185.7121942573082
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 375: -261.0584146309479
# Landung auf (0.22,-0.01) mit Geschwindigkeit = 0.01
#
# Episode 376: 188.50461650706734
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 377: 162.08519951212958
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 378: 176.3893443165426
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 379: 192.5735123049749
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 380: 152.57054813660685
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 381: 185.37865199071223
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 382: 169.00541984404728
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 383: 176.94451336936976
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 384: 149.9670995315159
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 385: 158.91602519620938
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 386: 123.23047112680466
# Landung auf (0.37,-0.05) mit Geschwindigkeit = 0.00
#
# Episode 387: 188.0227717043928
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 388: 155.4198084972095
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 389: 187.45145634187028
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 390: 169.32960301356462
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 391: 150.61122953101966
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 392: 152.67219105185612
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 393: 151.06458900978524
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 394: 126.72166780701137
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 395: -154.15447581306557
# Landung auf (-0.99,0.06) mit Geschwindigkeit = -0.11
#
# Episode 396: 189.21618375810445
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 397: 147.1874387067196
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 398: 154.686821852538
# Landung auf (-0.05,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 399: 152.25792917520977
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 400: 135.42661545476759
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 401: 184.69970926644584
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 402: 185.5446732164743
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 403: -313.67551482299234
# Landung auf (-0.12,0.01) mit Geschwindigkeit = -0.44
#
# Episode 404: 170.22660304749962
# Landung auf (0.01,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 405: 144.70112856115597
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 406: 193.13010652011224
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 407: -43.874351130560555
# Landung auf (-0.43,0.13) mit Geschwindigkeit = -0.22
#
# Episode 408: 185.663591356165
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 409: 160.84384371851448
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 410: 184.67720419620304
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 411: 130.26688511959853
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 412: 162.97698854589962
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 413: 161.58831870288302
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 414: 115.79467914867365
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 415: 160.95110958305273
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 416: 121.67730377873315
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 417: 175.68430015963602
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 418: 156.23622884576127
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 419: 155.36546104782477
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 420: 147.49868138483146
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 421: 178.66781033163042
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 422: 132.73413898566332
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 423: -407.03306893255836
# Landung auf (-0.74,-0.29) mit Geschwindigkeit = -1.15
#
# Episode 424: -97.2578803077334
# Landung auf (-0.35,0.08) mit Geschwindigkeit = -0.12
#
# Episode 425: -241.74086039226754
# Landung auf (-0.61,-0.01) mit Geschwindigkeit = -0.50
#
# Episode 426: 169.42077015463119
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 427: 128.75572259653163
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 428: -442.95493386518604
# Landung auf (0.36,-0.05) mit Geschwindigkeit = -0.69
#
# Episode 429: 151.73446509955184
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 430: 161.0802724615924
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 431: 150.9247969530285
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 432: 189.7052165783427
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 433: 163.36790873391047
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 434: 180.18338080577763
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 435: -487.0671227865227
# Landung auf (-0.97,0.01) mit Geschwindigkeit = -0.35
#
# Episode 436: 144.20782290994174
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 437: 175.62612729383557
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 438: 142.94837404901955
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 439: 160.32352887668182
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 440: 168.08032376258618
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 441: 178.30766384487276
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 442: 155.39048291974487
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 443: 164.31679839736643
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 444: 127.61129641848417
# Landung auf (-0.03,0.00) mit Geschwindigkeit = 0.00
#
# Episode 445: 176.53165986365522
# Landung auf (0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 446: 178.5590630193516
# Landung auf (-0.10,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 447: 122.67208682150408
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 448: 167.24219368791495
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 449: 153.95380232754337
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 450: 142.76828788210528
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 451: 152.9640112700956
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 452: 176.94714367772363
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 453: 151.09919547609823
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 454: 127.32553963826888
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 455: 160.60806679912463
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 456: 190.07600776451682
# Landung auf (0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 457: 183.79130885347658
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 458: 173.89828618230464
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 459: 128.78913520431263
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 460: 156.82941747474356
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 461: 170.40440427068904
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 462: 131.26374345614562
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 463: 148.3121622368106
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 464: 177.09274827876536
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 465: 131.67904669223483
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 466: 169.91151555192585
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 467: 175.30843335104015
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 468: 152.8857882238155
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 469: 140.91754627074954
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 470: 170.7098048823371
# Landung auf (-0.14,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 471: 174.4192912468804
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 472: 145.3876073955925
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 473: 180.45582117543137
# Landung auf (0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 474: 141.44643747230717
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 475: 145.99172273195634
# Landung auf (0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 476: 157.7458334665701
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 477: 174.85823417164514
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 478: 185.40308145450962
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 479: 174.16571597870248
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 480: 150.50469293478983
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 481: 180.3499381370643
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 482: 168.51380674303056
# Landung auf (0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 483: 163.7967510438652
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 484: 170.37378070875022
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 485: 184.78772546194043
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 486: 160.59198504224983
# Landung auf (0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 487: 186.83420468121366
# Landung auf (-0.04,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 488: 167.99719319126592
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 489: 178.73101533708515
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 490: 135.37542034432784
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 491: 187.63196255445942
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 492: 149.57409029025897
# Landung auf (-0.00,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 493: 173.46005646613088
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 494: 153.76255215886354
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 495: 156.79318564467098
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 496: 186.31785453494024
# Landung auf (-0.07,0.00) mit Geschwindigkeit = -0.00
#
# Episode 497: 189.00090943669383
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 498: 169.63260609877892
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 499: 142.89727728182007
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 500: -351.58187404853555
# Landung auf (-0.50,0.04) mit Geschwindigkeit = 0.02
#
# Episode 501: 125.29727621796225
# Landung auf (-0.19,0.01) mit Geschwindigkeit = -0.00
#
# Episode 502: 141.79274141049703
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 503: 195.02585909203523
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 504: -224.24456853775922
# Landung auf (-0.32,0.00) mit Geschwindigkeit = -0.78
#
# Episode 505: 171.8898731379786
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 506: 176.63626251806136
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 507: 166.52242207996233
# Landung auf (0.00,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 508: 135.66603974629467
# Landung auf (0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 509: 159.4362801699582
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 510: -394.92982653977674
# Landung auf (0.66,-0.04) mit Geschwindigkeit = -0.15
#
# Episode 511: 152.95576762131444
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 512: 204.46358446271745
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 513: 155.14990401691546
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 514: 147.52893664377024
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 515: 136.29760028007325
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 516: 197.18580002195822
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 517: 132.145676615967
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 518: 162.82310684734716
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 519: 180.35275008447923
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 520: 134.75262438434717
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 521: 171.08309176040189
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 522: 164.54546922320495
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 523: 172.03057524816188
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 524: 157.08604282178143
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 525: 146.76635947021597
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 526: 169.75129234406327
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 527: 134.94106562849444
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 528: 142.3702423362887
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 529: 162.70441874897216
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 530: 126.20872969221453
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 531: 142.45003171763753
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 532: 166.502997543479
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 533: 188.41047825750763
# Landung auf (-0.08,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 534: 168.73270103039627
# Landung auf (-0.09,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 535: 175.5488129598527
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 536: 186.64860104108013
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 537: 161.52508404127775
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 538: 126.21960018965638
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 539: 183.08133863877052
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 540: 133.94179718850827
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 541: 179.67462913756717
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 542: 152.7859812752102
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 543: 170.71773015168387
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 544: 162.01622217788437
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 545: 137.89792833358152
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 546: 173.4107204068039
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 547: 156.4633314218212
# Landung auf (0.10,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 548: 122.26770192158499
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 549: 163.09082175029502
# Landung auf (-0.08,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 550: 187.68050788369774
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 551: 160.08010937737447
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 552: 143.42295148884892
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 553: 138.80048662699585
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 554: -310.3107214436901
# Landung auf (0.98,-0.00) mit Geschwindigkeit = -0.17
#
# Episode 555: 159.6610337086419
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 556: 155.67667900291482
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 557: 192.3906431076915
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 558: 146.04030698223332
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 559: 173.54495556265942
# Landung auf (0.07,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 560: 157.798071210178
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 561: 158.80069930896988
# ...
#
# Episode 816: 175.81500289084707
# Landung auf (-0.00,0.00) mit Geschwindigkeit = -0.00
#
# Episode 817: 133.1068057371242
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 818: 158.7420086050244
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 819: 145.63817462326972
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 820: 169.7742650424097
# Landung auf (-0.08,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 821: 143.6131075810151
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 822: 166.80490912885074
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 823: 148.89138686201042
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 824: 190.50698755231204
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 825: 198.07643710409087
# Landung auf (0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 826: 173.40886055222902
# Landung auf (0.08,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 827: 182.19965324618425
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 828: 164.48389791493037
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 829: 126.06104879920571
# Landung auf (0.09,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 830: 160.17369777277602
# Landung auf (-0.00,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 831: 141.06760073958742
# Landung auf (0.14,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 832: 146.69961670318332
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 833: 173.55900578806921
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 834: 167.18676158393137
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 835: 161.22981667174975
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 836: 137.79421743280437
# Landung auf (0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 837: 145.22749467857503
# Landung auf (0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 838: 138.9005532435263
# Landung auf (0.01,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 839: 151.1304466938305
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 840: 176.1837469070058
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 841: 168.31050520953832
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 842: 177.89167623594338
# Landung auf (0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 843: 156.5083411406865
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 844: 160.43822733773317
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 845: 159.49241082185395
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 846: 152.28555425957353
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 847: 189.27725675379983
# Landung auf (0.04,0.00) mit Geschwindigkeit = -0.00
#
# Episode 848: 171.67901979939776
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 849: 135.54964551521275
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 850: 162.17727222930566
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 851: 154.3233709434303
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 852: 135.70141109667492
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 853: 132.19649872442346
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 854: 162.111612437535
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 855: 168.0121683554924
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 856: 132.53869007619704
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 857: 151.03665364009527
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 858: 199.05190878047077
# Landung auf (0.07,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 859: 166.24336889690434
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 860: 169.18234599286595
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 861: -232.20103391641018
# Landung auf (-0.98,0.04) mit Geschwindigkeit = -0.09
#
# Episode 862: 184.42941327268932
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 863: 178.5409598887892
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 864: 163.71512561596032
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 865: 170.2377088017808
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 866: 191.63763869443568
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 867: 128.9804356069029
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 868: 184.49526893804597
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 869: 147.61437821291275
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 870: 173.50197623398142
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 871: -538.2070425422814
# Landung auf (0.97,-0.18) mit Geschwindigkeit = -0.67
#
# Episode 872: 150.29688879470922
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 873: 172.74658789067416
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 874: 169.88146243867504
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 875: 192.64984003453804
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 876: 119.48876257936763
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 877: 159.4463597010049
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 878: 168.12319265529803
# Landung auf (0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 879: 193.96779765402212
# Landung auf (0.08,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 880: 176.6242208856221
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 881: 147.72927594732937
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 882: -329.29224271397425
# Landung auf (-0.42,0.11) mit Geschwindigkeit = -0.20
#
# Episode 883: 167.44678797517963
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 884: 146.9002288543342
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 885: 160.00112934031802
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 886: 169.84334970620915
# Landung auf (-0.10,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 887: 176.13108232158757
# Landung auf (0.05,0.00) mit Geschwindigkeit = -0.00
#
# Episode 888: 148.27139334082202
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 889: 156.33243905519504
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 890: 164.41541971496318
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 891: -452.070859422281
# Landung auf (0.98,0.20) mit Geschwindigkeit = -0.51
#
# Episode 892: -34.70175354302681
# Landung auf (0.33,0.07) mit Geschwindigkeit = 0.06
#
# Episode 893: 188.54691843504682
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 894: 133.07053332798466
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 895: 150.46815556847486
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 896: 148.48970869520087
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 897: 196.3475892065834
# Landung auf (-0.08,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 898: 157.20356602599023
# Landung auf (-0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 899: 166.6258494248476
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 900: 166.7678131119458
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 901: 126.45611047927522
# Landung auf (0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 902: 176.42324489769982
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 903: 174.57965317618525
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 904: 169.7240412399604
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 905: 172.84089749511884
# Landung auf (0.04,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 906: 147.12835450858066
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 907: 168.11956997075788
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 908: 152.03789990304608
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 909: 160.1498799434911
# Landung auf (-0.10,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 910: 165.08645675730182
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 911: 156.9000660209961
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 912: 159.3329812950005
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 913: 158.81977757697197
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 914: 150.934629432237
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 915: 172.80721124928226
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 916: 191.0236007547283
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 917: 133.6300809505192
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 918: 152.57619888308972
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 919: 162.9948966339466
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 920: 150.11789351457944
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 921: -284.2519483772086
# Landung auf (-0.99,0.23) mit Geschwindigkeit = -0.31
#
# Episode 922: 132.4711261456441
# Landung auf (0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 923: 187.31441297069193
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 924: 146.8132345970816
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 925: 187.45197038340112
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 926: 182.55481468491072
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 927: 182.23579389728232
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 928: 158.9873529217835
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 929: 136.74782784034323
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 930: 149.97728401318005
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 931: 152.29122820319014
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 932: 148.33674946824476
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 933: 169.65534105499796
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 934: 182.984763838323
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 935: 181.2276027041177
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 936: 159.05071012876624
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 937: 165.14891740392451
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 938: 165.9276446434365
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 939: 151.30920861514724
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 940: -521.526022601797
# Landung auf (-0.98,0.11) mit Geschwindigkeit = -0.50
#
# Episode 941: -275.8597319216689
# Landung auf (0.55,-0.06) mit Geschwindigkeit = -0.51
#
# Episode 942: 141.68903145548677
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 943: 145.2260633429883
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 944: 177.82882251985993
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 945: 181.47104126634758
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 946: 202.73327922691132
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 947: 174.9776947192436
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 948: -141.7701440650095
# Landung auf (-0.52,0.13) mit Geschwindigkeit = -0.10
#
# Episode 949: 166.7399266909899
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 950: 132.22311116649004
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 951: 173.0708155623005
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 952: 137.62827609200951
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 953: 143.74404924639202
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 954: -565.3104805239534
# Landung auf (-0.89,-0.10) mit Geschwindigkeit = -1.07
#
# Episode 955: 146.57436954847972
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 956: 147.54150707374458
# Landung auf (0.01,0.00) mit Geschwindigkeit = -0.00
#
# Episode 957: 162.99807154440265
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 958: 134.07787527517354
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 959: 179.1580221662205
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 960: 165.8855079530914
# Landung auf (-0.06,0.00) mit Geschwindigkeit = -0.00
#
# Episode 961: 131.86825375387446
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 962: 130.10079487989915
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 963: -331.2946341786261
# Landung auf (0.99,0.12) mit Geschwindigkeit = -0.37
#
# Episode 964: 140.05000381016177
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 965: 189.24641606430546
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 966: 174.81569921193528
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 967: 148.58024924424376
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 968: 181.7449286649062
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 969: 156.50688798644083
# Landung auf (0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 970: 162.2991155500525
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 971: 171.35095923974626
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 972: 148.7842319245446
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 973: 160.3833356502723
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 974: 138.5603990320807
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 975: 172.6335640235505
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 976: 144.34916666311315
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 977: 153.2890492008834
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 978: 178.76448368318557
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 979: 121.7859060127757
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 980: 124.07381775363767
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 981: 145.23729840000797
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 982: 148.69431621233215
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 983: 177.1536118216977
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 984: 162.6940694916903
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 985: 164.9857329281546
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 986: 173.86988655393944
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 987: 195.97444543886473
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 988: 123.83326117264156
# Landung auf (0.03,0.00) mit Geschwindigkeit = -0.00
#
# Episode 989: 169.93640857224796
# Landung auf (0.10,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 990: 169.0038994741953
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 991: 163.58152806096825
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 992: 172.2646332590832
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 993: 173.71547751454762
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 994: 194.4014888608851
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 995: 124.49468225146987
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 996: 184.15520958486272
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 997: 171.99900547703916
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 998: 181.09576734211805
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 999: 175.24241459892895
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 1000: 155.56182791046007
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Durchschnittliche Punktzahl über 1000 Episoden: 138.31187347697045
# Durchschnittliche Entfernung zu x=0.00 über 1000 Episoden: 0.060

# %%
# Plot: Scores über Episoden
plt.figure(figsize=(12, 6))
plt.plot(range(1, 1001), total_rewards, marker=".", label="Scores")
plt.plot(range(1, 1001), [np.mean(total_rewards[:x]) for x in range(1, 1001)], marker=".", label="Mean Score")
plt.title('Entwicklung des Scores über die Episoden')
plt.legend()
plt.xlabel('Episode')
plt.ylabel('Score')
plt.grid()
plt.show()

# %%
# Plot: Entfernung zu x=0
plt.figure(figsize=(12, 6))
plt.plot(range(1, 1001), x_cords, marker=".", label="X-Cord")
plt.plot(range(1, 1001), [np.mean(x_cords[:x]) for x in range(1, 1001)], marker=".", label="Mean Error")
plt.title('Entwicklung der Landungskoordinaten über die Episoden')
plt.legend()
plt.xlabel('Episode')
plt.ylabel('Abweichung von x=0.0')
plt.grid()
plt.show()

# %% [markdown]
# ## Fazit

# %% [markdown]
# Das Fazit zu diesem Projekt zeigt, dass der Einsatz eines PID-Controllers das gewünschte Ziel von 200 Punkten nicht erreicht hat, dennoch eine bemerkenswerte Leistung bei der Minimierung des Fehlers der Landungskoordinate x erzielt wurde. Die erzielten Scores liegen durchschnittlich im Bereich von 135 Punkten, wobei es zu häufigen ausreißenden Werten bis -650 Punkte kommen kann.
