# %% [markdown]
# # Evaluierung eines PID-gesteuerten Agenten in der LunarLander-v3-Umgebung

# %% [markdown]
# @Author Michael Greif

# %% [markdown]
# In dieser Demonstration wird die Leistung eines Agenten evaluiert, der mittels PID-Reglern in der LunarLander-v3-Umgebung von OpenAI Gym gesteuert wird. Die Aufgabe des Agenten besteht darin, ein Raumschiff sicher auf einer Plattform zu landen, wobei er drei wesentliche Dimensionen steuern muss:
#
# 1. **Vertikale Position**: Das Raumschiff soll sanft auf der Plattform landen.
# 2. **Horizontale Position**: Das Raumschiff soll über der Plattform zentriert bleiben.
# 3. **Winkel**: Das Raumschiff soll in einer aufrechten Position ohne Neigung landen.
#
# Für jede dieser Dimensionen wurde ein separater PID-Regler implementiert, um präzise Steuerbefehle basierend auf dem aktuellen Zustand des Raumschiffs zu generieren. Diese Regler helfen dabei, die Abweichungen vom gewünschten Zustand zu minimieren.
#
# Die Simulation wird über eine Reihe von Episoden durchgeführt, um die Effizienz dieser Steuerstrategie zu analysieren. Am Ende jeder Episode werden die Gesamtrewards und die Landungspunkte des Raumschiffs ausgegeben. Darüber hinaus wird eine statistische Auswertung über mehrere Episoden gegeben, um die durchschnittliche Punktezahl und die durchschnittliche Landungsgenauigkeit zu berechnen.

# %% [markdown]
# # Verwendete Bibliotheken

# %% [markdown]
# Bibliotheksreferenzen
# - OpenAI Gymnasium: https://gymnasium.farama.org/
# - NumPy: https://numpy.org/
# - Matplotlib: https://matplotlib.org/

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # PID Controller Class

# %% [markdown]
# Der PID-Controller im folgenden Code ist eine Implementierung eines Proportional-Integral-Derivative (PID) Reglers, der in Steuerungssystemen weit verbreitet ist. Dieser Regler zielt darauf ab, eine dynamische Prozesssteuerung zu ermöglichen, indem er kontinuierlich die Differenz (Fehler) zwischen einem gewünschten Sollwert und einem aktuellen Istwert analysiert und darauf reagiert. Der PID-Regler beeinflusst den Steuerungsoutput durch drei
#
# **Kernkomponenten**:
#
# - **Proportionaler Anteil (Kp)**: Dieser Teil des Reglers reagiert direkt proportional zum aktuellen Fehlerwert. Er veranlasst umso stärkere Anpassungen, je weiter der Istwert vom Sollwert abweicht. Ein gut abgestimmter Kp-Wert hilft, schnelle Korrekturen vorzunehmen, kann aber auch zu Instabilitäten führen, wenn er zu hoch ist.
#
# - **Integraler Anteil (Ki)**: Der Integralaspekt adressiert die Summe der vergangenen Fehler über die Zeit. Er korrigiert stetige Abweichungen, die sich im Zeitverlauf aufsummieren, und sorgt dafür, dass der Regler keine dauerhafte Diskrepanz zwischen Soll- und Istwert besitzt.
#
# - **Derivativer Anteil (Kd)**: Dieser Bestandteil gibt Aufschluss über die Geschwindigkeit der Fehlerveränderung und ist entscheidend zur Dämpfung des Systems. Er reduziert die Reaktion auf große Fehler, wenn der Istwert schnell auf den Sollwert zusteuert, und verhindert Überschwinger.
#
# Die Methode `update` des PID-Controllers berechnet den Steuerungsoutput basierend auf den Werten dieser drei Parameter und dem gegebenen Fehler. Die Methode `reset` dient zur Initialisierung der vorhergehenden Fehler und der Integralsumme, falls ein Neustart oder ein erneuter Steuerprozess notwendig ist.

# %%
class PIDController:
    def __init__(self, Kp, Ki, Kd):
        # Initialisiert den PID-Controller mit den gegebenen Koeffizienten
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.prev_error = 0
        self.integral = 0

    def reset(self):
        # Setzt die gespeicherten Zustände zurück
        self.prev_error = 0
        self.integral = 0

    def update(self, error, dt):
        # Berechnet den Ausgang des PID-Reglers auf Basis des aktuellen Fehlers
        self.integral += error * dt
        derivative = (error - self.prev_error) / dt
        output = self.Kp * error + self.Ki * self.integral + self.Kd * derivative
        self.prev_error = error
        return output

# %% [markdown]
# # Funktion zum Testen der Controller

# %% [markdown]
# Zu Beginn wird die Umgebung initialisiert und drei PID-Regler werden mit spezifischen Koeffizienten für proportionale, integrale und differentiale Anteile konfiguriert. Diese Regler steuern jeweils die vertikale Bewegung, die horizontale Bewegung und den Neigungswinkel des Raumschiffs.
#
# Die Simulation läuft über mehrere Episoden. In jeder Episode startet das Raumschiff in einem zufälligen Zustand, und die Regler werden zurückgesetzt, um Änderungen im Steuerungsverhalten zwischen den Episoden zu verhindern. Innerhalb jeder Episode berechnet der Code kontinuierlich die Differenz (Fehler) zwischen dem aktuellen und dem gewünschten Zustand des Raumschiffs. Anhand dieser Fehler bestimmen die PID-Regler entsprechende Steuerungsaktionen.
#
# Der Code umfasst eine Schleife, die bis zum Abschluss jeder Episode läuft. Während dieser Schleife werden die Steuerbefehle basierend auf den berechneten Fehlern aktualisiert, und die resultierenden Aktionen werden auf die Umgebung angewendet. Jede Aktion beeinflusst den Zustand des Raumschiffs und generiert eine Belohnung, die zur Gesamtbelohnung der Episode addiert wird. Wenn das Raumschiff sicher gelandet ist, wird die Episode beendet. Am Ende jeder Episode werden die erzielten Ergebnisse ausgegeben.
#
# Zusätzlich wird ein Überblick über die Leistung in allen durchgeführten Episoden gegeben. Die durchschnittlichen Belohnungen und die Präzision der Landungen werden ausgewertet, um die Effektivität der verwendeten PID-Regler zu beurteilen.

# %%
def evaluate_pid(n_episodes=5, verbose=0, render_mode=None):
    """
    Evaluierung eines PID-gesteuerten Agenten in der LunarLander-v3-Umgebung für eine bestimmte Anzahl von Episoden.

    :param n_episodes: Anzahl der Episoden, die ausgeführt werden sollen (Standardwert ist 5).
    :param verbose: Grad der Detailtiefe für Debug-Ausgaben (Standardwert ist 0, was keine Debug-Ausgabe bedeutet).
    :param render_mode: Modus zum Rendern der Umgebung (Standard ist None, was kein Rendering bedeutet).

    Die Funktion verwendet drei separate PID-Regler zur Steuerung der vertikalen Position, horizontalen Position und des Winkels des Landers. 
    Sie berechnet die Fehler zwischen dem aktuellen und dem gewünschten Zustand, aktualisiert die Aktionen über die PID-Regler und wendet 
    Aktionen auf die Umgebung an. Ziel jeder Episode ist es, das Raumschiff sicher auf der Plattform zu landen und die Geschwindigkeit 
    bei der Landung zu minimieren.
    """
    # Erstelle die Gym-Umgebung mit einer spezifischen Gravitätseinstellung
    env = gym.make("LunarLander-v3", gravity=-10.0, render_mode=render_mode)
    
    # Initialisiere PID-Regler für die vertikale, horizontale Steuerung und den Winkel
    vertical_pid = PIDController(Kp=4.0, Ki=0.5, Kd=1.0)
    horizontal_pid = PIDController(Kp=2.0, Ki=2.0, Kd=0.5)
    angle_pid = PIDController(Kp=4.0, Ki=2.0, Kd=0.3)
    
    total_rewards = []  # Liste zur Speicherung der Gesamtreward pro Episode
    x_cords = []          # Liste zur Speicherung der finalen x-Koordinate der Landung pro Episode

    # Schleife durch jede Episode
    for episode in range(n_episodes):
        state, _ = env.reset()  # Setze die Umgebung für eine neue Episode zurück
        vertical_pid.reset()    # Setze den vertikalen PID-Regler zurück
        horizontal_pid.reset()  # Setze den horizontalen PID-Regler zurück
        angle_pid.reset()       # Setze den Winkel-PID-Regler zurück
        total_reward = 0        # Akkumulator für den Gesamtreward
        done = False            # Flag zur Anzeige des Endes der Episode
        
        # Schleife, bis die Episode beendet ist
        while not done:
            # Entpacke den aktuellen Zustand
            coord_x, coord_y, velocity_x, velocity_y, angle, velocity_angle, left_foot, right_food = state
            
            # Zielzustände für die Steuerung (Sollwerte)
            target_y = 0.0
            target_x = 0.0
            target_angle = 0.0

            # Berechne die Fehler für jede Steuerungsdimension
            y_error = target_y - coord_y - velocity_y * 2
            x_error = target_x + coord_x + velocity_x * 2
            angle_error = target_angle - angle - velocity_angle
            
            # Zeitschritt für die PID-Aktualisierung
            dt = 1.0 / 50.0 

            # Aktualisiere die PID-Regler und erhalte die Steueraktionen
            y_action = vertical_pid.update(y_error, dt)
            x_action = horizontal_pid.update(x_error, dt)
            theta_action = angle_pid.update(angle_error, dt)
            
            if verbose:
                # Debug-Informationen ausgeben, wenn Verbosität aktiviert ist
                print("y: ", coord_y, "v: ", velocity_y, end=" ")
                print("Fehler: ", y_error, "Output: ", y_action)
                print("x: ", coord_x, "v: ", velocity_x, end=" ")
                print("Fehler: ", x_error, "Output: ", x_action)
                print()
            
            # Bestimme die Aktionen basierend auf den Steuerergebnissen
            vertical_action = 2 if y_action > 0 else 0
            horizontal_action = 1 if x_action > 0 else 3
            angle_action = 1 if theta_action > 0 else 3

            # Wähle die endgültige Aktion
            action = vertical_action
            if vertical_action == 0:
                action = horizontal_action if abs(x_action) > abs(theta_action) else angle_action

            # Wende die ausgewählte Aktion auf die Umgebung an
            state, reward, done, _, _ = env.step(action)
            if left_foot and right_food and abs(velocity_y) < 0.005:
                done = True  # Beende die Episode, wenn das Raumschiff erfolgreich landet
            total_reward += reward  # Summiere die Belohnung auf
        
        # Speichere die Ergebnisse der Episode
        x_cords.append(coord_x)
        total_rewards.append(total_reward)
        
        # Episode-Zusammenfassung ausgeben
        print(f"Episode {episode + 1}: {total_reward}")
        print(f"Landung auf ({coord_x:.2f},{coord_y:.2f}) mit Geschwindigkeit = {velocity_y:.2f}")
        print()
    
    env.close()  # Schließe die Umgebung, sobald alle Episoden abgeschlossen sind
    
    # Endergebnisse ausgeben
    print(f"Durchschnittliche Punktzahl über {episode + 1} Episoden: {np.mean(total_rewards)}")
    print(f"Durchschnittliche Entfernung zu x=0.00 über {episode + 1} Episoden: {abs(np.mean(x_cords)):.3f}")
    
    return total_rewards, x_cords

# %% [markdown]
# # Testing

# %% [markdown]
# Die Funktion `evaluate_pid` wird mit `n_episodes=1000` aufgerufen, um den PID-gesteuerten Agenten in der "LunarLander-v3"-Umgebung über 1000 Episoden auszuwerten. Dabei wird das Verhalten des Raumschiffs gesteuert, um es sicher auf einer Plattform zu landen. Die Funktion nutzt drei PID-Regler, um die vertikale und horizontale Bewegung sowie die Neigung des Raumschiffs zu kontrollieren. In jeder Episode wird der aktuelle Zustand des Raumschiffs kontinuierlich mit dem Zielzustand verglichen, um entsprechende Steuerbefehle zu berechnen und anzuwenden. Nach jeder Episode werden die Gesamtbelohnungen und Landungspräzisionen festgehalten, um die mittlere Leistung und Landungsgenauigkeit über alle 1000 Episoden hinweg zu bewerten. Dies ermöglicht eine umfassende Analyse der Effektivität und Anpassung der PID-Regler.

# %%
total_rewards, x_cords = evaluate_pid(n_episodes=1000)
# Out:
# Episode 1: 161.38104468179935
# Landung auf (-0.04,0.00) mit Geschwindigkeit = 0.00
#
# Episode 2: 132.21785998134487
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 3: 147.78592649071695
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 4: 123.00588162591451
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 5: 155.95773031018848
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 6: 179.77482738361846
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 7: 158.64689557131888
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 8: 153.1807517684987
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 9: -281.6222174391615
# Landung auf (0.13,0.01) mit Geschwindigkeit = -0.25
#
# Episode 10: -294.97427993090787
# Landung auf (0.13,0.02) mit Geschwindigkeit = -0.44
#
# Episode 11: -52.751684206308234
# Landung auf (1.00,0.09) mit Geschwindigkeit = -0.02
#
# Episode 12: 158.46874273019583
# Landung auf (-0.11,0.00) mit Geschwindigkeit = -0.00
#
# Episode 13: 168.57869711974107
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 14: 178.29073653220158
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 15: 168.95895303474745
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 16: 134.27026895232297
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 17: 157.09602133183407
# Landung auf (-0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 18: 164.92518134323873
# Landung auf (0.03,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 19: 166.06319883496076
# Landung auf (-0.03,0.00) mit Geschwindigkeit = -0.00
#
# Episode 20: 160.61338085507492
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 21: 150.01966270634753
# Landung auf (-0.05,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 22: 137.43355351467113
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 23: 152.2343530457387
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 24: 174.50671254756162
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 25: 138.9916977350201
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 26: 171.44249400432386
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 27: 182.28721997840395
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 28: 154.61547197762357
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 29: 189.04707680877397
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 30: -268.4879278362997
# Landung auf (-0.41,-0.08) mit Geschwindigkeit = -0.95
#
# Episode 31: 166.2504796602301
# Landung auf (-0.02,0.00) mit Geschwindigkeit = -0.00
#
# Episode 32: 153.65846719128515
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 33: -281.3577385408197
# Landung auf (-0.16,0.01) mit Geschwindigkeit = -0.55
#
# Episode 34: 141.5646410737778
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 35: 187.3394110230131
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 36: 174.62586560375811
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 37: 178.70324704805765
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 38: 175.82695147235637
# Landung auf (-0.07,0.00) mit Geschwindigkeit = -0.00
#
# Episode 39: 208.47061646162575
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 40: 159.01071309494324
# Landung auf (0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 41: 134.59451022156514
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 42: 128.0207529407815
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 43: 147.54516557234962
# Landung auf (-0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 44: 165.29378260985126
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 45: 124.14338372316212
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 46: 176.253958854617
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 47: 131.89576149343353
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 48: 145.79918093811065
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 49: 135.2390413155751
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 50: 170.8274954642592
# Landung auf (-0.00,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 51: 183.92935943988047
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 52: 165.85200428739606
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 53: 178.18183003466527
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 54: 173.7332110036448
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 55: 136.24703071638223
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 56: 157.9949170234962
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 57: 182.03731899365275
# Landung auf (-0.11,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 58: -478.24159830484336
# Landung auf (-0.88,0.04) mit Geschwindigkeit = -0.03
#
# Episode 59: 194.8269107269918
# Landung auf (0.09,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 60: 155.95332297248575
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 61: 182.14826411854833
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 62: 157.51633494114296
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 63: 164.947946128005
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 64: 165.84714443246608
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 65: -271.3773128682092
# Landung auf (0.20,0.02) mit Geschwindigkeit = -0.76
#
# Episode 66: 154.16788437914164
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 67: 166.08596134398485
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 68: 177.5682197383757
# Landung auf (-0.06,0.00) mit Geschwindigkeit = 0.00
#
# Episode 69: 162.04912585517752
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 70: 140.270746287114
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 71: 138.84585489682877
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 72: 172.5446337006103
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 73: 147.90154550842956
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 74: 137.82748012369754
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 75: -268.4160762935273
# Landung auf (0.12,0.01) mit Geschwindigkeit = -0.44
#
# Episode 76: 175.42869700980106
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 77: 168.538917235868
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 78: 186.95643671859258
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 79: 179.90779015237501
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 80: 181.10743250265568
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 81: 162.32643820907066
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 82: 162.69051399350053
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 83: 134.9053872540184
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 84: 157.13422837467903
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 85: 161.9892407924769
# Landung auf (0.05,0.00) mit Geschwindigkeit = -0.00
#
# Episode 86: 158.55714430870262
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 87: 116.98398657258429
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 88: 134.20487171454064
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 89: 187.21647242564995
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 90: 133.20462816092953
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 91: 153.3419374689478
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 92: 179.83466963167797
# Landung auf (0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 93: 150.07680458532815
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 94: 176.8541914117406
# Landung auf (0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 95: 157.16984900382164
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 96: 163.17975188320105
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 97: 148.3294931056273
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 98: 142.0057358542819
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 99: 168.1647676024415
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 100: -342.68511612396924
# Landung auf (-0.32,0.06) mit Geschwindigkeit = -0.52
#
# Episode 101: 169.87612884202028
# Landung auf (-0.00,0.00) mit Geschwindigkeit = -0.00
#
# Episode 102: 173.09088803321495
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 103: 163.43625207984388
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 104: 171.22910849075421
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 105: 153.28363654482484
# Landung auf (0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 106: -509.3653077800147
# Landung auf (0.83,-0.02) mit Geschwindigkeit = -0.84
#
# Episode 107: 191.19414594666495
# Landung auf (0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 108: 164.4590917136378
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 109: 149.31589313685345
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 110: 143.77374563915922
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 111: 182.3511946800715
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 112: 129.99631094844668
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 113: 174.89765397888374
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 114: 173.99686452061255
# Landung auf (-0.08,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 115: 167.11205314999552
# Landung auf (-0.07,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 116: 176.5662120267925
# Landung auf (0.10,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 117: 149.28849455489785
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 118: 173.50914540490518
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 119: -223.0426118052099
# Landung auf (0.66,-0.06) mit Geschwindigkeit = -0.53
#
# Episode 120: 185.21244423613078
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 121: 125.89336584061945
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 122: 143.0012050922064
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 123: 152.19646328883042
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 124: 177.41821559549868
# Landung auf (-0.04,0.00) mit Geschwindigkeit = -0.00
#
# Episode 125: 136.57957802692897
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 126: 158.7016964380337
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 127: -215.89570682138927
# Landung auf (-0.51,-0.10) mit Geschwindigkeit = -0.53
#
# Episode 128: 203.5108291583001
# Landung auf (0.08,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 129: 193.6971823208453
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 130: 156.71157853891242
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 131: 131.10782576566038
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 132: 124.66919333166261
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 133: 164.7538100525171
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 134: 186.683184504374
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 135: 150.97171929341323
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 136: 146.70343848557116
# Landung auf (-0.04,-0.03) mit Geschwindigkeit = 0.00
#
# Episode 137: 131.92997492004253
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 138: -269.0545544446236
# Landung auf (-0.02,0.02) mit Geschwindigkeit = -0.52
#
# Episode 139: 184.81158576593242
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 140: 155.78103750630788
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 141: 170.00259173379715
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 142: 162.1387295486809
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 143: 147.11974538714983
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 144: 186.72160727473673
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 145: 130.37715296142352
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 146: 152.8066888561405
# Landung auf (0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 147: 153.9241017213802
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 148: 175.1695040787039
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 149: 144.223039446227
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 150: 152.37800115704823
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 151: 148.4510866148474
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 152: 154.73801718743752
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 153: 187.35782303762153
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 154: 168.892028059695
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 155: 182.7594480409226
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 156: 135.2807247588375
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 157: 151.16541590980236
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 158: 165.23843573302906
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 159: 119.96500396096206
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 160: 171.69192597031304
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 161: 173.11720316646208
# Landung auf (-0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 162: 171.2054746144466
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 163: 202.61346750472708
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 164: 144.80161133951515
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 165: 170.927730526419
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 166: 157.66823838332255
# Landung auf (0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 167: 175.51944751547512
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 168: 185.57710006127837
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 169: 145.56534284218424
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 170: 144.77671917570785
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 171: 179.37964928814966
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 172: 150.20816644295743
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 173: 157.15108266591153
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 174: 177.27579791118046
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 175: 155.86190976935694
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 176: 161.56851310425188
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 177: 170.15397874467644
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 178: 163.0250084047907
# Landung auf (0.01,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 179: 132.86167350284106
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 180: 149.03573558747527
# Landung auf (-0.00,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 181: 170.9178326304263
# Landung auf (-0.06,0.00) mit Geschwindigkeit = -0.00
#
# Episode 182: 154.27456350676346
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 183: 163.58930560664706
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 184: 171.80514468596837
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 185: 182.66428408339823
# Landung auf (0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 186: 148.38620359601984
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 187: 140.03565471128718
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 188: 147.1613017222424
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 189: -300.6756787988445
# Landung auf (0.16,0.02) mit Geschwindigkeit = -0.45
#
# Episode 190: 150.83103428302715
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 191: 179.6037173678036
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 192: 143.72805741762247
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 193: 163.2544056054051
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 194: 168.22524055263082
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 195: 182.30615312370517
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 196: -374.43299557141995
# Landung auf (0.41,0.12) mit Geschwindigkeit = -0.29
#
# Episode 197: 167.77670913474333
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 198: 164.93478549314221
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 199: -370.7980832434149
# Landung auf (-0.44,-0.00) mit Geschwindigkeit = -0.50
#
# Episode 200: 156.88434606111724
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 201: 165.94706637507713
# Landung auf (0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 202: 130.7737001961511
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 203: 157.37229662117352
# Landung auf (-0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 204: 167.893840979089
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 205: 184.33518118893434
# Landung auf (-0.10,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 206: 176.20651648932193
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 207: 167.24501089887124
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 208: 166.85791172414244
# Landung auf (-0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 209: 181.5396852604455
# Landung auf (-0.00,-0.03) mit Geschwindigkeit = -0.00
#
# Episode 210: 181.23512983321598
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 211: 164.64354384937062
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 212: 150.12438169102126
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 213: -90.63820491728568
# Landung auf (0.37,0.12) mit Geschwindigkeit = -0.24
#
# Episode 214: 189.09055647826676
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 215: 167.14740495500763
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 216: 139.57664988879327
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 217: 182.49548100439844
# Landung auf (-0.08,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 218: 170.6249602809457
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 219: 161.74121793337454
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 220: 206.2298494985467
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 221: 188.09892209487583
# Landung auf (0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 222: 178.79404997020984
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 223: 166.23642138657056
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 224: 179.5521313778088
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 225: 168.47149710922082
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 226: 191.25664845885595
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 227: 149.53410962103482
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 228: 191.4554068474563
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 229: 179.66073987203646
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 230: 180.71554281714685
# Landung auf (0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 231: 170.29028500147825
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 232: 191.49653206018053
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 233: 173.60373354299944
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 234: 170.08325958410384
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 235: -275.20751808199554
# Landung auf (-0.31,0.11) mit Geschwindigkeit = -0.33
#
# Episode 236: 185.30307199203506
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 237: 176.5718189569557
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 238: -360.18999260791065
# Landung auf (-0.22,0.00) mit Geschwindigkeit = -0.72
#
# Episode 239: 168.94323690992874
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 240: 181.46758627745902
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 241: 149.69233563298494
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 242: 172.19216457964694
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 243: 197.36915001962103
# Landung auf (0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 244: 193.2110150117529
# Landung auf (-0.11,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 245: 164.62662964522346
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 246: 159.07340641051854
# Landung auf (0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 247: 177.61555123504093
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 248: -210.3639218478266
# Landung auf (0.33,-0.05) mit Geschwindigkeit = -0.33
#
# Episode 249: 149.67101718290021
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 250: 164.0713742099899
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 251: 171.04557454034136
# Landung auf (0.07,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 252: 172.7228311761673
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 253: 184.99200102817784
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 254: 176.4265002412607
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 255: 153.91917791578476
# Landung auf (0.01,0.00) mit Geschwindigkeit = -0.00
#
# Episode 256: 142.9096076900775
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 257: 170.5396996538569
# Landung auf (0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 258: 171.73342450523947
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 259: 166.5877799388874
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 260: 200.10123443231
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 261: 155.15169405416984
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 262: 155.10145800275038
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 263: 142.86369467012116
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 264: 184.58657762879784
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 265: 165.91336960083422
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 266: 155.8642631044594
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 267: 162.40823538427796
# Landung auf (0.11,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 268: 156.2849734301763
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 269: 161.81223573414317
# Landung auf (0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 270: 127.09390874770772
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 271: 169.68027321456862
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 272: 179.9632841136582
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 273: 183.0552861031748
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 274: 193.725377318428
# Landung auf (0.00,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 275: 171.00581818188581
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 276: 113.2831039254168
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 277: -282.55427500765586
# Landung auf (-0.86,-0.05) mit Geschwindigkeit = -0.44
#
# Episode 278: 152.5881897862179
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 279: 159.70077162957176
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 280: 153.46031929868144
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 281: 130.9337754850601
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 282: 150.9092513366727
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 283: 148.03303659895846
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 284: 136.6486583942887
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 285: 157.20499052009748
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 286: 159.18563501041024
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 287: 169.91614159154457
# Landung auf (0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 288: -269.1237419503691
# Landung auf (-0.09,0.01) mit Geschwindigkeit = -0.50
#
# Episode 289: 199.95793747634102
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 290: 178.94112468824605
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 291: 129.45441220135993
# Landung auf (0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 292: 163.57674887284827
# Landung auf (-0.10,0.00) mit Geschwindigkeit = -0.00
#
# Episode 293: 184.804683802081
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 294: 172.736418451853
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 295: 158.61392216141763
# Landung auf (0.00,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 296: 184.84435873461433
# Landung auf (-0.10,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 297: 177.99006515514873
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 298: 172.74576783515772
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 299: 171.59145417348188
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 300: 155.34444600123916
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 301: 126.99470448123083
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 302: 156.9635369194821
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 303: 171.16533190630915
# Landung auf (0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 304: 163.1026669088279
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 305: 143.42553234305277
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 306: 180.02886675898566
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 307: 127.02415780857623
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 308: 185.56931976922297
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 309: 171.1279602411351
# Landung auf (0.04,0.00) mit Geschwindigkeit = -0.00
#
# Episode 310: 178.5336948320556
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 311: -378.46254781410335
# Landung auf (-0.50,0.18) mit Geschwindigkeit = -0.15
#
# Episode 312: 169.27743488169276
# Landung auf (0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 313: 152.40024626707302
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 314: 176.23648906273738
# Landung auf (-0.00,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 315: 169.80715423557547
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 316: 175.89616102225506
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 317: 156.053672591316
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 318: 146.015703597651
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 319: 131.43467384586768
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 320: 140.01432775544183
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 321: 150.18440765396386
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 322: 175.7016948517858
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 323: 157.5898230497213
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 324: 188.78848697064794
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 325: 153.87533680735822
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 326: 158.06049428730046
# Landung auf (0.00,0.00) mit Geschwindigkeit = -0.00
#
# Episode 327: 168.77991866918936
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 328: 137.28590316255682
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 329: 173.69832797438656
# Landung auf (-0.04,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 330: 160.1068238512384
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 331: 144.97819236206632
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 332: 174.50194725872308
# Landung auf (-0.00,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 333: -379.5801005397091
# Landung auf (-0.26,0.07) mit Geschwindigkeit = -0.93
#
# Episode 334: 149.12581296215106
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 335: 173.24341119467573
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 336: 143.43304938092075
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 337: 145.31991253315664
# Landung auf (0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 338: 175.42702148193524
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 339: 153.93028532491957
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 340: 170.4779135012677
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 341: 167.6673782147955
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 342: 150.57122298264233
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 343: 178.50106175386023
# Landung auf (-0.07,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 344: 177.28494164854024
# Landung auf (0.04,-0.03) mit Geschwindigkeit = 0.00
#
# Episode 345: 163.20283643471538
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 346: 142.1922911712748
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 347: 154.71936549576117
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 348: 158.57438194457944
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 349: 182.55297227206088
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 350: 152.0729314014028
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 351: 173.8281391543137
# Landung auf (-0.11,0.00) mit Geschwindigkeit = -0.00
#
# Episode 352: 187.9789207112445
# Landung auf (-0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 353: 172.6386355779988
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 354: 205.6337406438289
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 355: 170.0048700578327
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 356: 132.69315343808088
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 357: 144.53474759685108
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 358: 151.3712130706019
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 359: 141.9318309907898
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 360: 134.7441830874884
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 361: 158.9105446959774
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 362: 168.6864532213507
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 363: 162.1391891283983
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 364: 174.70376468731402
# Landung auf (-0.08,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 365: 147.91042450882745
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 366: 193.10266055642873
# Landung auf (0.12,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 367: 135.61992450327682
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 368: 168.22813002145207
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 369: 174.83381784901079
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 370: 147.1386077205285
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 371: 196.49712570247223
# Landung auf (-0.05,0.00) mit Geschwindigkeit = -0.00
#
# Episode 372: 184.23740214050036
# Landung auf (-0.06,0.00) mit Geschwindigkeit = 0.00
#
# Episode 373: 137.48978633504782
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 374: 171.2418202252401
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 375: 148.79016386828746
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 376: 163.4981665178362
# Landung auf (-0.15,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 377: 170.20950628235863
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 378: 155.29155721758397
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 379: 132.03499583399534
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 380: 168.93723896115014
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 381: 119.25734639447312
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 382: 160.36738703056224
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 383: 168.88367819955644
# Landung auf (0.09,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 384: 172.30923210850742
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 385: 166.50437889066046
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 386: 175.31871182421938
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 387: 198.83772515077547
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 388: 150.9553509125728
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 389: 174.96555260903835
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 390: 168.243367005145
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 391: 158.85715355106328
# Landung auf (-0.10,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 392: 171.16656956872745
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 393: 141.10763546721915
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 394: 153.7922191510176
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 395: 140.7546511354075
# Landung auf (0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 396: 133.4379829585832
# Landung auf (0.03,0.00) mit Geschwindigkeit = -0.00
#
# Episode 397: 168.35762384214107
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 398: 149.95772481837852
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 399: 181.87150255416395
# Landung auf (0.00,-0.03) mit Geschwindigkeit = 0.00
#
# Episode 400: 141.15586352428352
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 401: 163.80795521389243
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 402: 177.78832425987727
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 403: 126.18014232545238
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 404: 149.2384179790675
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 405: 144.62684382248497
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 406: 145.5200355870235
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 407: 186.07476849665903
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 408: 159.8603123947688
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 409: 128.85567651471146
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 410: -14.75387257830053
# Landung auf (-0.40,0.05) mit Geschwindigkeit = -0.14
#
# Episode 411: 191.80506665602383
# Landung auf (-0.04,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 412: 183.9721819103226
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 413: 119.68568890602928
# Landung auf (0.02,0.00) mit Geschwindigkeit = -0.00
#
# Episode 414: 191.66092378114746
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 415: 149.1285064016602
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 416: 133.28382023862252
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 417: 181.29689539943934
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 418: 143.00374907204818
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 419: 144.4090223643166
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 420: 152.51729331184
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 421: 183.54426896589817
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 422: 146.86344181203577
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 423: 145.11386575198057
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 424: 153.7862277573741
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 425: 146.3912974043703
# Landung auf (0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 426: 147.74349353722457
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 427: 174.3730956137794
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 428: 162.20468601366048
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 429: 124.04344668950388
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 430: 154.596517026004
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 431: 165.37173395026073
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 432: 161.6364322428033
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 433: 142.28779568675407
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 434: 150.79491717831314
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 435: 171.74146762503773
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 436: 169.87171933870468
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 437: -202.26095324660693
# Landung auf (0.40,-0.09) mit Geschwindigkeit = -0.41
#
# Episode 438: 191.73940322721907
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 439: 158.21366690886978
# Landung auf (0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 440: 150.95659924710674
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 441: 152.570617905746
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 442: 168.5382926251835
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 443: 145.83110454087415
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 444: 149.998255692619
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 445: 171.72059625078654
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 446: -109.54022126439477
# Landung auf (0.99,0.30) mit Geschwindigkeit = 0.06
#
# Episode 447: 182.6355400278278
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 448: 153.34387610005305
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 449: 175.62218886820276
# Landung auf (0.08,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 450: 151.6879858137664
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 451: 170.5164296828639
# Landung auf (0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 452: 151.99115464363268
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 453: 176.9986489431343
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 454: 165.74242138967463
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 455: 158.74133201758522
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 456: 186.4583029453222
# Landung auf (0.08,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 457: 188.01331242294546
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 458: 162.64588464192516
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 459: 183.74232492643694
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 460: -322.3415379964071
# Landung auf (0.31,0.04) mit Geschwindigkeit = -0.27
#
# Episode 461: 165.13485105003906
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 462: 157.28695682280144
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 463: 149.8949257029195
# Landung auf (0.00,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 464: 145.3806335449413
# Landung auf (0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 465: -276.2323436763258
# Landung auf (-0.11,0.01) mit Geschwindigkeit = -0.48
#
# Episode 466: -274.1864159477322
# Landung auf (-0.05,0.01) mit Geschwindigkeit = -0.54
#
# Episode 467: 164.4469803336381
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 468: 137.89192681446738
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 469: 158.82093361746482
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 470: 182.72774815916546
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 471: 135.4871378869346
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 472: -653.2061348134506
# Landung auf (-0.97,0.04) mit Geschwindigkeit = -0.71
#
# Episode 473: 129.66334021774603
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 474: 134.1813509482807
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 475: 182.93068123685708
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 476: 187.92341579894142
# Landung auf (0.07,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 477: 134.87049912922353
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 478: 181.81099137877578
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 479: 179.9102728886812
# Landung auf (0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 480: -119.3050139179983
# Landung auf (0.48,0.13) mit Geschwindigkeit = -0.14
#
# Episode 481: 149.26897388647689
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 482: 183.2903471178205
# Landung auf (0.08,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 483: 148.510117205177
# Landung auf (0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 484: 154.75076794875997
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 485: 169.7051456059011
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 486: 157.91075500496063
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 487: 138.52267917627867
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 488: 170.06576009107368
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 489: 135.2272779773577
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 490: 182.68232111819603
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 491: 203.52848234912852
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 492: 174.12179794700387
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 493: 185.01950316988632
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 494: 160.77094491700203
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 495: 175.92262985495074
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 496: 151.7525338996305
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 497: 164.8194904021487
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 498: 163.57311861455122
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 499: 188.3670490431731
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 500: 112.23863706051448
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 501: 175.18268628261498
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 502: 161.4136576364836
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 503: 162.86191449513495
# Landung auf (-0.03,-0.03) mit Geschwindigkeit = 0.00
#
# Episode 504: 196.32876966006268
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 505: 141.86577114127016
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 506: 173.04914920457375
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 507: 178.29282114283575
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 508: 128.26389840051098
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 509: 181.329219580126
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 510: -139.0966285059993
# Landung auf (0.62,0.08) mit Geschwindigkeit = -0.00
#
# Episode 511: 149.3037071914328
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 512: 143.55613441385435
# Landung auf (0.28,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 513: 174.0328926502542
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 514: 130.1271244259568
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 515: 165.34151214325425
# Landung auf (0.01,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 516: 191.163306216128
# Landung auf (0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 517: -20.79009517281368
# Landung auf (-0.34,0.08) mit Geschwindigkeit = -0.14
#
# Episode 518: 182.465502153209
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 519: 157.81153624485756
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 520: 157.56071889057245
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 521: 181.21780075547434
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 522: 151.49941814136872
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 523: 177.2896907952981
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 524: 178.05623535019456
# Landung auf (-0.08,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 525: 160.73756067767198
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 526: 140.41576437740932
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 527: 162.94635503898547
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 528: 128.5324463526934
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 529: 169.35921431012864
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 530: 194.6316612503217
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 531: 125.67575421601836
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 532: 169.01102870344516
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 533: 162.7145317648402
# Landung auf (0.02,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 534: 182.46117322642604
# Landung auf (0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 535: 156.22189979250658
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 536: 165.9799271961831
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 537: 186.70838263175688
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 538: 157.92297770571903
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 539: 167.63365011647733
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 540: 161.77628573473223
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 541: 176.13497769540288
# Landung auf (0.02,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 542: 157.4723632470875
# Landung auf (0.04,0.00) mit Geschwindigkeit = -0.00
#
# Episode 543: 155.09153234496927
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 544: 137.19741162152425
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 545: 163.79545179639263
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 546: 157.8893430734197
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 547: 151.0105515925369
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 548: 178.59880171101634
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 549: 163.10671710887425
# Landung auf (0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 550: 163.91275829965204
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 551: -29.89617172476507
# Landung auf (0.36,0.07) mit Geschwindigkeit = -0.15
#
# Episode 552: 136.61133884032552
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 553: 117.17089825446249
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 554: 184.95385878460092
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 555: 168.08636804285243
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 556: 147.81296991126388
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 557: 164.835076818908
# Landung auf (0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 558: 131.24267304704364
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 559: 174.35711109747237
# Landung auf (0.08,0.00) mit Geschwindigkeit = -0.00
#
# Episode 560: -261.1122131621918
# Landung auf (0.06,0.01) mit Geschwindigkeit = -0.39
#
# Episode 561: 160.09896103851372
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 562: 133.72597534937958
# ...
#
# Episode 816: 162.49805390915617
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 817: 142.0352215108878
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 818: 149.81007859159172
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 819: 141.1381630342457
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 820: 163.29670309390255
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 821: 143.75822790744522
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 822: 184.31134374441234
# Landung auf (0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 823: 160.4623270005501
# Landung auf (0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 824: -456.64847640067694
# Landung auf (0.45,0.03) mit Geschwindigkeit = -1.16
#
# Episode 825: 153.1832483976022
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 826: 165.0374312171508
# Landung auf (0.02,0.00) mit Geschwindigkeit = -0.00
#
# Episode 827: 199.1342377874545
# Landung auf (0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 828: -130.60736021106723
# Landung auf (0.87,0.02) mit Geschwindigkeit = -0.11
#
# Episode 829: 145.5047701746151
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 830: 161.0308505741446
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 831: 148.99048325567037
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 832: 195.6640531410833
# Landung auf (0.07,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 833: 173.6866514667225
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 834: 116.72718021802491
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 835: 132.17374719517645
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 836: 150.07443623439167
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 837: 165.18562238197282
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 838: 182.84667319501014
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 839: 130.36611498323242
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 840: 180.13402414831964
# Landung auf (-0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 841: 176.98389425579379
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 842: 154.9500069109241
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 843: 158.01172647631142
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 844: 172.944803782273
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 845: -422.2227341498308
# Landung auf (-0.73,0.19) mit Geschwindigkeit = -0.12
#
# Episode 846: 170.43903114138354
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 847: 181.84450366995512
# Landung auf (0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 848: 123.52357637955879
# Landung auf (-0.03,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 849: 140.16361310938925
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 850: 168.64457125753302
# Landung auf (-0.04,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 851: 174.64624026476756
# Landung auf (0.00,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 852: 160.2444647706052
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 853: 169.2080126926299
# Landung auf (0.00,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 854: 201.95963701447678
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 855: 135.13184688121203
# Landung auf (0.04,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 856: 168.61657336893018
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 857: 170.16261159430047
# Landung auf (-0.05,0.00) mit Geschwindigkeit = 0.00
#
# Episode 858: -168.79608384764964
# Landung auf (-1.00,-0.01) mit Geschwindigkeit = -0.05
#
# Episode 859: 180.6120140230854
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 860: 177.107904582727
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 861: 132.4190170185917
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 862: 179.70768767364126
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 863: -277.6536866951692
# Landung auf (-0.18,0.02) mit Geschwindigkeit = -0.61
#
# Episode 864: 158.51872428429266
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 865: 179.3952892615476
# Landung auf (-0.08,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 866: 162.0064709903329
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 867: 176.75862480471463
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 868: 165.736277056039
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 869: 146.4335394858979
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 870: -340.77120063361815
# Landung auf (0.49,-0.16) mit Geschwindigkeit = -0.64
#
# Episode 871: 172.2013022403102
# Landung auf (0.03,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 872: 185.9740946173435
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 873: 180.37651169303018
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 874: 168.2610862032371
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 875: 192.79171353185012
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 876: 162.51119483229488
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 877: -240.26355099619266
# Landung auf (-0.33,-0.09) mit Geschwindigkeit = -0.03
#
# Episode 878: 180.02242604336388
# Landung auf (0.10,0.00) mit Geschwindigkeit = -0.00
#
# Episode 879: 178.07412937610783
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 880: 157.24114516523676
# Landung auf (0.01,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 881: 134.42313635245992
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 882: 163.93368925940024
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 883: 171.83587176194175
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 884: 143.53741070252556
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 885: 166.1171706283599
# Landung auf (0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 886: 150.15156154485248
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 887: 182.69209983701325
# Landung auf (0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 888: 162.375331921129
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 889: 147.13273429016496
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 890: 144.43525781579186
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 891: 152.5081388115972
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 892: 173.786229953078
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 893: 160.13648716873843
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 894: 147.21796548790414
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 895: 173.1039553585057
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 896: 156.7840153788596
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 897: 164.6761352362638
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 898: 135.92045596568875
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 899: 141.9560641250175
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 900: 130.21245707502965
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 901: 177.72375307734805
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 902: 129.48924445609282
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 903: 166.54476325132757
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 904: 187.68223690156447
# Landung auf (-0.05,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 905: 155.5663202567052
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 906: 189.59843865195572
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 907: 194.82837036260597
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 908: 149.8821727866241
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 909: 150.64611525755416
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 910: 175.8796367520104
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 911: 161.71936068087174
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 912: 154.5802779662516
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 913: 149.45041012250172
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 914: 183.1183466574422
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 915: 140.46140981559773
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 916: 169.10748024343482
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 917: 142.64048456493157
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 918: 137.89148971984176
# Landung auf (0.26,0.02) mit Geschwindigkeit = -0.00
#
# Episode 919: 180.12282221505978
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 920: 174.21218876178756
# Landung auf (-0.05,-0.02) mit Geschwindigkeit = -0.00
#
# Episode 921: 124.0007363473191
# Landung auf (0.08,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 922: 155.78372091114213
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 923: 170.64118315224502
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 924: 184.17497354665431
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 925: 180.86498452403717
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 926: 163.984388590451
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 927: 161.51176240959458
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 928: 171.59081554434252
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 929: 163.68283086029606
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 930: 183.86951172639755
# Landung auf (-0.08,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 931: 190.99763637880136
# Landung auf (0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 932: 126.5961316283096
# Landung auf (0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 933: 171.1765395181017
# Landung auf (0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 934: 130.69839219296173
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 935: 154.5974306827264
# Landung auf (0.03,-0.02) mit Geschwindigkeit = 0.00
#
# Episode 936: 179.6671734173306
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 937: 150.93650387881075
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 938: 154.31060965324107
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 939: -78.7369604397393
# Landung auf (0.41,0.06) mit Geschwindigkeit = -0.14
#
# Episode 940: 183.80502003095043
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 941: 148.75949328611384
# Landung auf (0.05,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 942: 207.28263010778113
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 943: 175.26170853786866
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 944: 185.50186351992824
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 945: 171.55655509638387
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 946: 179.23588055110113
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 947: 191.75113366798288
# Landung auf (-0.07,0.00) mit Geschwindigkeit = -0.00
#
# Episode 948: -375.112350263427
# Landung auf (-0.52,0.15) mit Geschwindigkeit = -0.17
#
# Episode 949: 153.32919166258165
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 950: 123.92007514882809
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 951: 154.8926820025682
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 952: 150.5063727318805
# Landung auf (0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 953: 144.54895047937106
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 954: -259.4492683501883
# Landung auf (0.51,-0.11) mit Geschwindigkeit = -0.85
#
# Episode 955: 159.26452501855272
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 956: 120.79912496765355
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 957: 167.08644415249532
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 958: 143.12610540975083
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 959: 160.41026148345318
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 960: 178.51201151112127
# Landung auf (-0.10,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 961: 187.88286549202178
# Landung auf (-0.02,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 962: 130.51237246781494
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 963: 188.25451544053487
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 964: 147.69459255717678
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 965: 171.8674064844973
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 966: 188.87967539288977
# Landung auf (0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 967: 177.55067116678117
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 968: 180.78283640675335
# Landung auf (-0.03,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 969: 177.32495772929474
# Landung auf (-0.01,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 970: 169.15449847960429
# Landung auf (-0.06,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 971: 167.52631697851072
# Landung auf (0.09,0.00) mit Geschwindigkeit = -0.00
#
# Episode 972: -213.74302923528094
# Landung auf (0.26,-0.02) mit Geschwindigkeit = -0.03
#
# Episode 973: 191.9122717363264
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 974: 162.62298214696645
# Landung auf (-0.03,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 975: 153.3111411524251
# Landung auf (0.01,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 976: -194.75818457463552
# Landung auf (-0.65,0.14) mit Geschwindigkeit = -0.21
#
# Episode 977: 191.523515497098
# Landung auf (0.09,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 978: 124.28694199110633
# Landung auf (0.04,-0.01) mit Geschwindigkeit = 0.00
#
# Episode 979: 151.49423703847668
# Landung auf (0.00,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 980: 167.51405182106785
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 981: 165.83564216772734
# Landung auf (-0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 982: 189.95604059731994
# Landung auf (-0.07,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 983: 138.23813791267983
# Landung auf (0.05,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 984: 192.52369457710603
# Landung auf (-0.03,0.00) mit Geschwindigkeit = -0.00
#
# Episode 985: 156.50266894933097
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 986: 157.21805077532306
# Landung auf (-0.00,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 987: 168.96434940891933
# Landung auf (0.01,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 988: 191.6662639325158
# Landung auf (0.02,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 989: 154.03635539207818
# Landung auf (0.03,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 990: 181.79581822233524
# Landung auf (-0.06,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 991: 166.4481539418645
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 992: 193.83733977788404
# Landung auf (0.03,0.00) mit Geschwindigkeit = -0.00
#
# Episode 993: 120.67440259210362
# Landung auf (-0.00,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 994: 139.34220729772767
# Landung auf (-0.05,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 995: 176.33363233934296
# Landung auf (0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 996: 146.6855515259852
# Landung auf (0.04,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 997: 201.88792555595876
# Landung auf (0.02,-0.00) mit Geschwindigkeit = 0.00
#
# Episode 998: 151.89484026983646
# Landung auf (0.02,-0.01) mit Geschwindigkeit = -0.00
#
# Episode 999: 149.43516996029643
# Landung auf (-0.04,-0.00) mit Geschwindigkeit = -0.00
#
# Episode 1000: 111.0607764022539
# Landung auf (-0.01,-0.00) mit Geschwindigkeit = -0.00
#
# Durchschnittliche Punktzahl über 1000 Episoden: 133.97808577458446
# Durchschnittliche Entfernung zu x=0.00 über 1000 Episoden: 0.004

# %%
# Plot: Scores über Episoden
plt.figure(figsize=(12, 6))
plt.plot(range(1, 1001), total_rewards, marker=".", label="Scores")
plt.plot(range(1, 1001), [np.mean(total_rewards[:x]) for x in range(1, 1001)], marker=".", label="Mean Score")
plt.title('Entwicklung des Scores über die Episoden')
plt.legend()
plt.xlabel('Episode')
plt.ylabel('Score')
plt.grid()
plt.show()

# %%
# Plot: Entfernung zu x=0
plt.figure(figsize=(12, 6))
plt.plot(range(1, 1001), x_cords, marker=".", label="X-Cord")
plt.plot(range(1, 1001), [np.mean(x_cords[:x]) for x in range(1, 1001)], marker=".", label="Mean Error")
plt.title('Entwicklung der Landungskoordinaten über die Episoden')
plt.legend()
plt.xlabel('Episode')
plt.ylabel('Abweichung von x=0.0')
plt.grid()
plt.show()
