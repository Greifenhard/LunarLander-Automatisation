# %% [markdown]
# # Automatisierte Lösung für OpenAIs LunarLander mit genetischen Algorithmen in Verbindung mit PID-Controllern

# %% [markdown]
# @Autor Michael Greif

# %% [markdown]
# ## Benutzte Bibliotheken

# %% [markdown]
# Bibliotheksreferenzen
# - OpenAI Gymnasium: https://gymnasium.farama.org/
# - NumPy: https://numpy.org/
# - Random: https://docs.python.org/3/library/random.html
# - Matplotlib: https://matplotlib.org/

# %%
import gymnasium as gym
import numpy as np
import random
import matplotlib.pyplot as plt

# %% [markdown]
# ## PID-Controller

# %% [markdown]
# Der PID-Controller im folgenden Code ist eine Implementierung eines Proportional-Integral-Derivative (PID) Reglers, der in Steuerungssystemen weit verbreitet ist. Dieser Regler zielt darauf ab, eine dynamische Prozesssteuerung zu ermöglichen, indem er kontinuierlich die Differenz (Fehler) zwischen einem gewünschten Sollwert und einem aktuellen Istwert analysiert und darauf reagiert. Der PID-Regler beeinflusst den Steuerungsoutput durch drei
#
# **Kernkomponenten**:
#
# - **Proportionaler Anteil (Kp)**: Dieser Teil des Reglers reagiert direkt proportional zum aktuellen Fehlerwert. Er veranlasst umso stärkere Anpassungen, je weiter der Istwert vom Sollwert abweicht. Ein gut abgestimmter Kp-Wert hilft, schnelle Korrekturen vorzunehmen, kann aber auch zu Instabilitäten führen, wenn er zu hoch ist.
#
# - **Integraler Anteil (Ki)**: Der Integralaspekt adressiert die Summe der vergangenen Fehler über die Zeit. Er korrigiert stetige Abweichungen, die sich im Zeitverlauf aufsummieren, und sorgt dafür, dass der Regler keine dauerhafte Diskrepanz zwischen Soll- und Istwert besitzt.
#
# - **Derivativer Anteil (Kd)**: Dieser Bestandteil gibt Aufschluss über die Geschwindigkeit der Fehlerveränderung und ist entscheidend zur Dämpfung des Systems. Er reduziert die Reaktion auf große Fehler, wenn der Istwert schnell auf den Sollwert zusteuert, und verhindert Überschwinger.
#
# Die Methode `update` des PID-Controllers berechnet den Steuerungsoutput basierend auf den Werten dieser drei Parameter und dem gegebenen Fehler. Die Methode `reset` dient zur Initialisierung der vorhergehenden Fehler und der Integralsumme, falls ein Neustart oder ein erneuter Steuerprozess notwendig ist.

# %%
class PIDController:
    def __init__(self, Kp, Ki, Kd):
        # Initialisiert den PID-Controller mit den gegebenen Koeffizienten
        self.Kp = Kp
        self.Ki = Ki
        self.Kd = Kd
        self.prev_error = 0
        self.integral = 0

    def reset(self):
        # Setzt die gespeicherten Zustände zurück
        self.prev_error = 0
        self.integral = 0

    def update(self, error, dt):
        # Berechnet den Ausgang des PID-Reglers auf Basis des aktuellen Fehlers
        self.integral += error * dt
        derivative = (error - self.prev_error) / dt
        output = self.Kp * error + self.Ki * self.integral + self.Kd * derivative
        self.prev_error = error
        return output

# %% [markdown]
# ## Genetischer Trainingsalgorithmus

# %% [markdown]
# Die `GeneticAlgorithm`-Klasse stellt eine Methode zur Optimierung von PID-Parameter-Sätzen dar, um die Steuerungseffizienz des LunarLanders in der OpenAI Gym-Umgebung zu maximieren. Der genetische Algorithmus ist von biologischen Evolutionstechniken inspiriert und beinhaltet die Prinzipien der natürlichen Selektion, Kreuzung und Mutation, um über Generationen hinweg qualitativ hochwertige Lösungen zu entwickeln.
#
# **Hauptkomponenten der `GeneticAlgorithm`-Klasse**:
# - **Initialisierung**: Der Algorithmus beginnt mit einer zufällig generierten Population von Individuen, wobei jedes Individuum einen Satz von neun PID-Parameterwerten repräsentiert.
#
# - **Fitnessfunktion**: Jedes Individuum wird basierend auf seiner Fähigkeit bewertet, den Lander in der simulierten Umgebung zu steuern. Die Fitness wird durch den erzielten durchschnittlichen Score über mehrere Episoden hinweg ermittelt, wobei dieser Score die Effektivität des PID-Reglers widerspiegelt.
#
# - **Mutation und Crossover**: Die Methoden zur Mutation und Kreuzung erlauben es dem Algorithmus, neue Individuen zu generieren. Mutationen bringen zufällige Veränderungen ein, während die Kreuzung es zwei Elternteilen ermöglicht, ihre Eigenschaften zu einem Kind zu kombinieren. Diese Mechanismen tragen zur genetischen Vielfalt bei und helfen dem Algorithmus, lokale Maxima zu vermeiden.
#
# - **Iterative Optimierung**: Der Algorithmus durchläuft mehrere Generationen und wählt die fittesten Individuen aus jeder Generation aus, um eine neue Population zu erstellen. Im Laufe der Zeit sollte sich die Gesamtfitness der Population erhöhen, was zur Identifizierung der am besten geeigneten PID-Parameter für die Steuerung des Landers führt.
#
# Am Ende der Ausführung liefert die `run`-Methode den besten gefundenen Satz an PID-Parametern sowie eine Historie der Fitnesswerte der besten Individuen aus jeder Generation, was wertvolle Einblicke in die Optimierungsleistung des Algorithmus bietet

# %%
class GeneticAlgorithm:
    def __init__(self, population_size, mutation_rate, num_generations, n_episodes):
        """
        Initialisiert die Parameter des genetischen Algorithmus.
        
        Parameters:
        - population_size: Die Anzahl der Individuen in der Population.
        - mutation_rate: Die Rate, mit der Mutationen auftreten.
        - num_generations: Die Anzahl der Generationen, über die der Algorithmus läuft.
        - n_episodes: Die Anzahl der Episoden zur Bewertung der Individuenfitness.
        """
        self.population_size = population_size
        self.mutation_rate = mutation_rate
        self.num_generations = num_generations
        self.n_episodes = n_episodes

    def initialize_population(self):
        """
        Erzeugt eine initiale Population mit zufälligen Individuen.
        
        Returns:
        - Eine Liste von zufällig initialisierten Individuen.
        """
        return [np.random.rand(9) * 4.0 for _ in range(self.population_size)]

    def fitness(self, individual):
        """
        Bewertet die Fitness eines Individuums durch Simulation in der Umgebung.
        
        Parameters:
        - individual: Ein Array aus PID-Parametern, das bewertet wird.
        
        Returns:
        - Der durchschnittliche erzielte Score über alle Episoden.
        """
        vertical_params = individual[0:3]
        horizontal_params = individual[3:6]
        angle_params = individual[6:9]
        
        env = gym.make("LunarLander-v3", render_mode=None, gravity=-10.0)
        vertical_pid = PIDController(*vertical_params)
        horizontal_pid = PIDController(*horizontal_params)
        angle_pid = PIDController(*angle_params)
        
        total_rewards = []
        
        for episode in range(self.n_episodes):
            state, _ = env.reset()
            vertical_pid.reset()
            horizontal_pid.reset()
            angle_pid.reset()
            total_reward = 0
            done = False
            
            while not done:
                coord_x, coord_y, velocity_x, velocity_y, angle, velocity_angle, left_foot, right_food = state
                
                # Zielwerte definiert
                target_y = 0.0
                target_x = 0.0
                target_angle = 0.0

                # Fehlerberechnungen
                y_error = target_y - coord_y - velocity_y * 2
                x_error = target_x + coord_x + velocity_x * 2
                angle_error = target_angle - angle - velocity_angle
                
                dt = 1.0 / 50.0 

                # Berechnet die Actions basierend auf den PID-Updates
                y_action = vertical_pid.update(y_error, dt)
                x_action = horizontal_pid.update(x_error, dt)
                theta_action = angle_pid.update(angle_error, dt)

                # Bestimmt vertikale, horizontale und Winkelaktionen
                vertical_action = 2 if y_action > 0 else 0
                horizontal_action = 1 if x_action > 0 else 3
                angle_action = 1 if theta_action > 0 else 3

                action = vertical_action
                if vertical_action == 0:
                    action = horizontal_action if abs(x_action) > abs(theta_action) else angle_action

                state, reward, done, _, _ = env.step(action)
                if left_foot and right_food and abs(velocity_y) < 0.005:
                    done = True
                total_reward += reward
            
            total_rewards.append(total_reward)

        env.close()
        return np.mean(total_rewards)

    def mutate(self, individual):
        """
        Führt Mutationen an einem Individuum durch.
        
        Parameters:
        - individual: Ein zu mutierendes Individuum.
        
        Returns:
        - Das mutierte Individuum.
        """
        for i in range(individual.shape[0]):
            if np.random.rand() < self.mutation_rate:
                individual[i] += np.random.normal(0, 1)
        return individual

    def crossover(self, parent1, parent2):
        """
        Kombiniert zwei Elternteile zu einem neuen Kind-Individuum.
        
        Parameters:
        - parent1: Erster Eltern-Individuum.
        - parent2: Zweiter Eltern-Individuum.
        
        Returns:
        - Das erzeugte Kind-Individuum.
        """
        assert len(parent1) == len(parent2) == 9, "Beide Elternteile sollten 9 Elemente haben"
        crossover_point = np.random.randint(len(parent1))
        child = np.concatenate((parent1[:crossover_point], parent2[crossover_point:]))
        return child

    def run(self):
        """
        Führt den genetischen Algorithmus aus, um den besten PID-Parameter-Satz zu finden.

        Returns:
        - best_individual: Das beste gefundene Individuum mit optimierten PID-Parametern.
        - total_fitness: Eine Liste der Fitnesswerte der besten Individuen über Generationen.
        """
        total_fitness = []
        population = self.initialize_population()

        for generation in range(self.num_generations):
            population_fitness = [self.fitness(ind) for ind in population]
            sorted_indices = np.argsort(population_fitness)
            population = [population[i] for i in sorted_indices]
            best_individual = population[-1]
            print(f"Generation {generation + 1}, Best Fitness: {population_fitness[sorted_indices[-1]]}")
            total_fitness.append(population_fitness[sorted_indices[-1]])

            # Elitismus: Übernimmt die besten Individuen in die nächste Generation
            next_generation = population[-int(0.1 * self.population_size):]

            # Fülle die restliche Population mit Nachkommen gefüllt
            while len(next_generation) < self.population_size:
                parent1, parent2 = random.sample(population[-20:], 2)
                child = self.crossover(parent1, parent2)
                self.mutate(child)
                next_generation.append(child)

            population = next_generation

        return best_individual, total_fitness

# %% [markdown]
# ## Testfunktion der PID-Controller

# %% [markdown]
# Die Funktion `play_with_best_params` ermöglicht es, die Effektivität eines optimierten Satzes von PID-Parameterwerten direkt in der „LunarLander-v3“-Gym-Umgebung zu evaluieren. Diese Funktion stellt sicher, dass die Leistungsfähigkeit der zuvor mittels des genetischen Algorithmus ermittelten besten Parameter überprüft und veranschaulicht wird.
#
# **Hauptbestandteile der `play_with_best_params`-Funktion**:
# - **Umgebungskonfiguration**: Es wird eine LunarLander-v3-Umgebung mit einer einstellbaren Darstellung (`render_mode`) und einem modifizierten Gravitationswert erstellt, um realistische Testbedingungen zu simulieren.
#
# - **PID-Regler**: Drei PID-Regler werden auf Basis der übergebenen Parameter für die vertikale Position, horizontale Bewegung und Neigung (Winkel) des Landers initialisiert. Diese Regler berechnen kontinuierlich die erforderlichen Anpassungen, um den Lander stabil und präzise zu steuern.
#
# - **Episode-Kontinuum**: In einer festgelegten Anzahl von Episoden (`n_episodes`) wird der Verlauf simuliert. Innerhalb jeder Episode wird der Lander in der Umgebung durch einen iterativen Regelprozess gesteuert:
#
#   1. **Fehlerberechnungen**: Die Funktion berechnet kontinuierlich die Fehler im Vergleich zu den Zielzuständen für Position und Winkel.
#
#   2. **PID-Updates**: Basierend auf den berechneten Fehlern und der verstrichenen Zeit (`dt`) steuert der PID-Regler die Bodenantriebsaktionen des Landers.
#
#   3. **Aktionsentscheidung**: Basierend auf den PID-Outputs werden die Steueraktionen des Landers entschieden, um die Richtung und Intensität der Triebwerke zu bestimmen.
#
#   4. **Sammeln von Ergebnissen**: Jeder Durchgang endet, wenn der Lander erfolgreich landet (bei geringen Geschwindigkeiten) und das Episode-Ergebnis (Score) wird aufgezeichnet.
#
# - Ausgabe der Leistung: Nach allen Episoden wird der mittlere erzielte Score über alle Durchläufe zusammen mit Details zu jedem Landeversuch ausgegeben. Dies ermöglicht eine Analyse, wie gut die optimierten PID-Parameter in realen Szenarien funktionieren.

# %%
def play_with_best_params(params, n_episodes=10, render_mode=None):
    """
    Testet die Leistung der besten PID-Parameter in der LunarLander-Umgebung.
    
    Parameters:
    - params: Eine Liste von PID-Parametern in der Form [Kp1, Ki1, Kd1, Kp2, Ki2, Kd2, Kp3, Ki3, Kd3].
    - n_episodes: Die Anzahl der Episoden, die in der Simulation abgespielt werden sollen.
    - render_mode: Der Modus der Darstellung, standardmäßig auf 'human' für visuelle Ausgabe gesetzt.
    """
    # Initialisiert die Umgebung für den LunarLander
    env = gym.make("LunarLander-v3", render_mode=render_mode, gravity=-10.0)
    
    # Erzeugt PID-Regler mit den übergebenen Parametern
    vertical_pid = PIDController(*params[:3])
    horizontal_pid = PIDController(*params[3:6])
    angle_pid = PIDController(*params[6:9])
    
    total_rewards = []
    err = []

    for episode in range(n_episodes):
        state, _ = env.reset()
        vertical_pid.reset()
        horizontal_pid.reset()
        angle_pid.reset()
        total_reward = 0
        done = False
        
        while not done:
            coord_x, coord_y, velocity_x, velocity_y, angle, velocity_angle, left_foot, right_food = state
            
            # Definiert Zielwerte als Referenzpunkte
            target_y = 0.0
            target_x = 0.0
            target_angle = 0.0

            # Berechnet die Abweichungen bezüglich der Ziele
            y_error = target_y - coord_y - velocity_y * 2
            x_error = target_x + coord_x + velocity_x * 2
            angle_error = target_angle - angle - velocity_angle
            
            dt = 1.0 / 50.0  # Zeitdifferenz für die PID-Berechnung

            # Aktualisiert die PID-Regler und erhält Steueraktionen
            y_action = vertical_pid.update(y_error, dt)
            x_action = horizontal_pid.update(x_error, dt)
            theta_action = angle_pid.update(angle_error, dt)

            # Bestimmt die Aktionsstrategie basierend auf den PID-Ausgaben
            vertical_action = 2 if y_action > 0 else 0
            horizontal_action = 1 if x_action > 0 else 3
            angle_action = 1 if theta_action > 0 else 3

            # Setzt die tatsächliche Aktion für die Umgebung
            action = vertical_action
            if vertical_action == 0:
                action = horizontal_action if abs(x_action) > abs(theta_action) else angle_action

            state, reward, done, _, _ = env.step(action)
            
            # Beendet die Episode, wenn erfolgreich gelandet
            if left_foot and right_food and abs(velocity_y) < 0.005:
                done = True
            total_reward += reward

        err.append(abs(coord_x))
        
        total_rewards.append(total_reward)
        print(f"Episode {episode}: {total_reward}")
        print(f"Landing on ({coord_x:.2f},{coord_y:.2f}) with velocity = {velocity_y:.2f}")

    env.close()
    # Ausgabe der durchschnittlichen Belohnung aller Episoden
    print(f"\nMean Reward over {n_episodes} episode(s): {np.mean(total_rewards)}")
    
    return total_rewards, err

# %% [markdown]
# ## Training

# %% [markdown]
# Im Trainingsteil des Projekts wird die `GeneticAlgorithm`-Klasse instanziiert, um eine evolutionäre Suche nach den besten Satz von PID-Parametern für die gezielte Steuerung des LunarLanders durchzuführen.
#
# **Trainieren des genetischen Algorithmus**:
# - **Parameterinitialisierung**: Der genetische Algorithmus wird mit bestimmten Parametern eingerichtet:
#
#     1. Eine `population_size` von 75 garantiert, dass eine signifikante Anzahl individueller PID-Parameterkombinationen untersucht wird.
#     2. Die `mutation_rate` von 0.1 sorgt für regelmäßige genetische Veränderungen innerhalb der Population, um die Vielfalt zu erhalten und die Möglichkeit zu geben, aus lokalen Optima auszubrechen.
#     3. Der Algorithmus ist konfiguriert, über `num_generations` von 50 zu laufen, was genug Iterationsschritte für die Konvergenz zu einem optimalen Lösungspunkt bereitstellen sollte.
#     4. `n_episodes` von 10 bestimmt die Anzahl der Testepisoden, die verwendet werden, um den Fitnesswert eines jeden Individuums während des Trainingsprozesses zu bewerten.
#
# - **Ausführung des genetischen Algorithmus**: Durch die Methode `run` des `GA_PARAMS` Objekts wird der gesamte evolutive Suchprozess gestartet.
#
#     1. Dabei arbeitet der Algorithmus daran, über die definierte Anzahl an Generationen hinweg die bestmöglichen PID-Parameter zu identifizieren.
#     2. Das Training gibt die besten gefundenen PID-Parameter (`best_pid_params`) zurück, sowie eine Aufzeichnung der Gesamtfitness während des Trainingspfads (`total_fitness_training`), die nützliche Informationen über den Fortschritt und die Entwicklung der Fitnesswerte liefern kann.

# %%
GA_PARAMS = GeneticAlgorithm(
        population_size=75,
        mutation_rate=0.1,
        num_generations=50,
        n_episodes=10
    )

# Ausführen des genetischen Algorithmus um die besten PID-Parameter zu erhalten
best_pid_params, total_fitness_training = GA_PARAMS.run()
# Out:
# Generation 1, Best Fitness: 113.73180967896363
# Generation 2, Best Fitness: 130.89727265935863
# Generation 3, Best Fitness: 157.66254515614767
# Generation 4, Best Fitness: 159.12827428279815
# Generation 5, Best Fitness: 151.22921519015725
# Generation 6, Best Fitness: 154.15362254807698
# Generation 7, Best Fitness: 162.34208425275966
# Generation 8, Best Fitness: 166.9419160075187
# Generation 9, Best Fitness: 163.62369827528417
# Generation 10, Best Fitness: 168.03804472059068
# Generation 11, Best Fitness: 170.41154796039797
# Generation 12, Best Fitness: 171.65563682149437
# Generation 13, Best Fitness: 177.96062305898687
# Generation 14, Best Fitness: 168.87230224309369
# Generation 15, Best Fitness: 174.3797560844182
# Generation 16, Best Fitness: 173.67012943572112
# Generation 17, Best Fitness: 173.4912611394811
# Generation 18, Best Fitness: 173.77640900310993
# Generation 19, Best Fitness: 175.38614237938845
# Generation 20, Best Fitness: 171.58064712831182
# Generation 21, Best Fitness: 171.39932261139296
# Generation 22, Best Fitness: 175.42001607836787
# Generation 23, Best Fitness: 174.90493274807244
# Generation 24, Best Fitness: 179.21254620801088
# Generation 25, Best Fitness: 175.76318887929204
# Generation 26, Best Fitness: 179.30722947307768
# Generation 27, Best Fitness: 177.58213270699864
# Generation 28, Best Fitness: 174.50398595179828
# Generation 29, Best Fitness: 175.74314984602626
# Generation 30, Best Fitness: 176.4287174475446
# Generation 31, Best Fitness: 179.92580554980435
# Generation 32, Best Fitness: 175.31243403679477
# Generation 33, Best Fitness: 182.90456672816237
# Generation 34, Best Fitness: 177.95533655975242
# Generation 35, Best Fitness: 181.25452188553956
# Generation 36, Best Fitness: 175.47040920312287
# Generation 37, Best Fitness: 180.24155732471647
# Generation 38, Best Fitness: 177.39887859888836
# Generation 39, Best Fitness: 177.27928064530903
# Generation 40, Best Fitness: 177.98733128603118
# Generation 41, Best Fitness: 176.773212941429
# Generation 42, Best Fitness: 184.4361231695145
# Generation 43, Best Fitness: 175.4978074214917
# Generation 44, Best Fitness: 183.21506876248552
# Generation 45, Best Fitness: 175.3951466775124
# Generation 46, Best Fitness: 178.7734660492709
# Generation 47, Best Fitness: 172.87775767846364
# Generation 48, Best Fitness: 179.60261036710443
# Generation 49, Best Fitness: 175.42668323119443
# Generation 50, Best Fitness: 178.63388744146351

# %%
# Ausgabe der besten PID-Parameter
print("Best PID Parameters:")
print("Vertical PID:", best_pid_params[:3])
print("Horizontal PID:", best_pid_params[3:6])
print("Angle PID:", best_pid_params[6:9])
# Out:
# Best PID Parameters:
# Vertical PID: [1.99809622 0.19102046 0.39780094]
# Horizontal PID: [2.83510795 1.17029399 0.18463194]
# Angle PID: [5.43696081 0.93697825 0.66193342]

# %%
# Plot: des Lernfortschritts
plt.figure(figsize=(12, 6))
plt.plot(range(GA_PARAMS.num_generations), total_fitness_training, marker='o')
plt.title('Entwicklung des besten Scores über Generationen')
plt.xlabel('Generation')
plt.ylabel('Best Score')
plt.grid()
plt.show()

# %% [markdown]
# Der obige Plot illustriert die Entwicklung des besten Scores im Verlauf des genetischen Trainings über 50 Generationen. Man erkennt zu Beginn eine deutliche Verbesserung der Scores, was darauf hindeutet, dass die Population schnell geeignete PID-Parameterkombinationen evaluiert und selektiert.
#
# Zwischen den Generationen 10 und 30 gibt es gewisse Schwankungen, die durch die natürliche Variation und Rekombination innerhalb der Population bedingt sind. Jedoch zeigt der Trend insgesamt, dass sich die Scores stabilisieren und im Bereich von 170 bis 180 Punkten einpendeln, was auf eine erfolgreiche Konvergenz hinweist.

# %% [markdown]
# ## Evaluation

# %%
# Evaluation der besten Parameter auf 1000 Testszenarien
print("\nPlaying with the best parameters...\n")
total_rewards, err = play_with_best_params(best_pid_params, n_episodes=1000)
# Out:
# Playing with the best parameters...
#
# Episode 0: 154.89218415074325
# Landing on (0.00,-0.00) with velocity = -0.00
# Episode 1: 169.8292863603044
# Landing on (-0.02,-0.00) with velocity = -0.00
# Episode 2: 175.04523278218716
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 3: 186.00035395367246
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 4: 186.37580330197338
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 5: 181.90900766170995
# Landing on (0.04,-0.01) with velocity = -0.00
# Episode 6: 118.53988078322303
# Landing on (-0.01,-0.00) with velocity = 0.00
# Episode 7: 198.48889276517173
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 8: 181.70327864452312
# Landing on (-0.06,-0.00) with velocity = -0.00
# Episode 9: 153.28767359583847
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 10: 188.7589704422264
# Landing on (0.00,-0.01) with velocity = 0.00
# Episode 11: 184.78034417144107
# Landing on (-0.00,-0.01) with velocity = 0.00
# Episode 12: 146.2781051142459
# Landing on (0.03,-0.00) with velocity = -0.00
# Episode 13: 146.85092114403366
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 14: 193.47935948829186
# Landing on (0.03,-0.00) with velocity = -0.00
# Episode 15: 188.53553517382784
# Landing on (-0.00,-0.00) with velocity = -0.00
# Episode 16: 135.21997508721
# Landing on (0.00,0.00) with velocity = -0.00
# Episode 17: 163.29966015015302
# Landing on (-0.04,-0.00) with velocity = 0.00
# Episode 18: 179.23195964332635
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 19: 195.72170109424394
# Landing on (0.07,-0.00) with velocity = -0.00
# Episode 20: 165.9890574035554
# Landing on (0.00,-0.00) with velocity = 0.00
# Episode 21: 192.8397573607557
# Landing on (-0.04,-0.00) with velocity = 0.00
# Episode 22: 169.76083542294415
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 23: 154.23267197884294
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 24: 169.97671401158357
# Landing on (0.06,-0.00) with velocity = 0.00
# Episode 25: 161.4659278621106
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 26: 132.44244009024456
# Landing on (0.02,-0.01) with velocity = -0.00
# Episode 27: 182.32425210891122
# Landing on (-0.00,-0.00) with velocity = -0.00
# Episode 28: 180.67015311198628
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 29: 166.44506587938835
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 30: 164.43250813874693
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 31: 193.53837204454192
# Landing on (-0.05,-0.00) with velocity = -0.00
# Episode 32: 184.20479833706577
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 408: 191.85730000430826
# Landing on (-0.05,-0.00) with velocity = -0.00
# Episode 409: 190.36540295819535
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 410: 168.36551028103506
# Landing on (-0.02,-0.00) with velocity = -0.00
# Episode 411: 149.2262716095603
# Landing on (0.01,-0.01) with velocity = -0.00
# Episode 412: 164.68191817413137
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 413: 157.26404445061368
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 414: 152.5319605373618
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 415: 161.96612686606338
# Landing on (-0.01,-0.01) with velocity = -0.00
# Episode 416: 199.9076895574043
# Landing on (0.03,-0.00) with velocity = -0.00
# Episode 417: 191.28996644822377
# Landing on (0.06,-0.00) with velocity = 0.00
# Episode 418: 176.90577663104668
# Landing on (0.00,-0.00) with velocity = -0.00
# Episode 419: 190.9484124606453
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 420: 192.3567355368118
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 421: 157.51507164731035
# Landing on (0.03,-0.01) with velocity = 0.00
# Episode 422: 175.73881689031484
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 423: 145.70523170488462
# Landing on (-0.02,-0.01) with velocity = 0.00
# Episode 424: 118.85103135238057
# Landing on (0.06,0.00) with velocity = 0.00
# Episode 425: 158.41476209932515
# Landing on (-0.01,-0.00) with velocity = 0.00
# Episode 426: 154.81666009032907
# Landing on (-0.01,0.00) with velocity = 0.00
# Episode 427: 147.70436306623068
# Landing on (0.07,-0.00) with velocity = 0.00
# Episode 428: 165.63989425586212
# Landing on (-0.07,-0.00) with velocity = -0.00
# Episode 429: 132.31233972844296
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 430: 195.12862389081826
# Landing on (0.05,-0.00) with velocity = -0.00
# Episode 431: 150.0470663142845
# Landing on (0.07,-0.00) with velocity = -0.00
# Episode 432: 150.06055748940207
# Landing on (0.01,-0.02) with velocity = -0.00
# Episode 433: 120.67413422163716
# Landing on (0.04,-0.01) with velocity = -0.00
# Episode 434: 187.24939937474429
# Landing on (-0.05,-0.00) with velocity = -0.00
# Episode 435: 164.27117052264254
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 436: 144.6313119210117
# Landing on (-0.04,-0.00) with velocity = 0.00
# Episode 437: 171.9808323158748
# Landing on (0.05,-0.00) with velocity = -0.00
# Episode 438: 138.87071796624758
# Landing on (0.05,0.00) with velocity = 0.00
# Episode 439: 182.60358111177945
# Landing on (-0.01,-0.01) with velocity = -0.00
# Episode 440: 170.8510661944634
# Landing on (-0.06,0.00) with velocity = -0.00
# Episode 441: 185.3135942457604
# Landing on (0.02,-0.01) with velocity = -0.00
# Episode 442: 154.80585470280388
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 443: 137.13124282526172
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 444: 181.40922632291196
# Landing on (-0.03,-0.01) with velocity = -0.00
# Episode 445: 181.8015784534885
# Episode 483: 178.39453611807537
# Landing on (-0.06,-0.01) with velocity = -0.00
# Episode 484: 205.24473791215627
# Landing on (-0.02,-0.01) with velocity = 0.00
# Episode 485: 168.00756401593176
# Landing on (-0.05,-0.00) with velocity = -0.00
# Episode 486: 152.60781842142595
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 487: 194.7546069691917
# Landing on (-0.03,-0.01) with velocity = 0.00
# Episode 488: 177.61608134863317
# Landing on (-0.05,-0.00) with velocity = 0.00
# Episode 489: 166.63762937426353
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 490: 188.28921168759572
# Landing on (-0.04,-0.00) with velocity = 0.00
# Episode 491: 177.0799102571128
# Landing on (-0.04,-0.01) with velocity = 0.00
# Episode 492: 127.5016253094473
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 493: 170.81146880615378
# Landing on (0.01,-0.01) with velocity = -0.00
# Episode 494: 137.3674756138406
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 495: 175.94810918572426
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 496: 193.38576517582106
# Landing on (0.00,-0.00) with velocity = 0.00
# Episode 497: 162.38396451789944
# Landing on (-0.03,-0.01) with velocity = 0.00
# Episode 498: 202.15649687272472
# Landing on (-0.03,-0.01) with velocity = 0.00
# Episode 499: 178.20931887121282
# Landing on (0.05,-0.00) with velocity = -0.00
# Episode 500: 170.94480366592222
# Landing on (0.01,-0.01) with velocity = 0.00
# Episode 501: 145.9257065293595
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 502: 172.64939306584932
# Landing on (0.03,-0.01) with velocity = 0.00
# Episode 503: 176.1215569649506
# Landing on (-0.04,-0.01) with velocity = -0.00
# Episode 504: 170.86260030093044
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 505: 159.22126761049861
# Landing on (-0.03,-0.01) with velocity = -0.00
# Episode 506: 155.4015762901395
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 507: 172.58337914236478
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 508: 180.67811772976486
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 509: 201.36582930750092
# Landing on (-0.04,-0.01) with velocity = -0.00
# Episode 510: 190.0747808350846
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 511: 140.96490910129194
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 512: 158.1834071654264
# Landing on (0.00,-0.00) with velocity = -0.00
# Episode 513: 170.7255122632475
# Landing on (0.00,-0.00) with velocity = 0.00
# Episode 514: 178.31356581335842
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 515: 136.50407302050007
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 516: 167.95708642337502
# Landing on (0.02,-0.01) with velocity = -0.00
# Episode 517: 163.53146379177423
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 518: 184.78823266792847
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 519: 147.54103962294147
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 520: 172.89181903008924
# Landing on (-0.05,-0.00) with velocity = -0.00
# Episode 521: 167.94399555921882
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 522: 160.5640185216969
# Landing on (0.04,-0.00) with velocity = -0.00
# Episode 523: 173.83000132817602
# Landing on (0.04,-0.01) with velocity = 0.00
# Episode 524: 163.9454079111626
# Landing on (0.05,-0.00) with velocity = -0.00
# Episode 525: 190.2139761796952
# Landing on (0.06,-0.00) with velocity = 0.00
# Episode 526: 187.24393957134998
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 527: 192.42041776057044
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 528: 164.87661768311148
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 529: -255.2551414592323
# Landing on (-0.91,0.17) with velocity = -0.07
# Episode 530: 162.00718329559288
# Landing on (0.04,-0.00) with velocity = -0.00
# Episode 531: 140.03015662075322
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 532: 138.37985509523097
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 533: 157.42765920691446
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 534: 195.99838646581497
# Landing on (0.07,0.00) with velocity = 0.00
# Episode 535: -54.28914467897919
# Landing on (0.58,0.05) with velocity = -0.11
# Episode 536: 186.2428428013014
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 537: 162.34539827770675
# Landing on (-0.01,-0.00) with velocity = 0.00
# Episode 538: 169.9142188132851
# Landing on (0.04,-0.00) with velocity = -0.00
# Episode 539: 157.84256442939218
# Landing on (-0.02,-0.00) with velocity = -0.00
# Episode 540: 158.38877860904728
# Landing on (0.06,-0.00) with velocity = 0.00
# Episode 541: -578.0007106011806
# Landing on (1.00,0.05) with velocity = -0.36
# Episode 542: 184.39246955836197
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 543: 119.42009028272423
# Landing on (0.03,-0.01) with velocity = 0.00
# Episode 544: 152.89543986447578
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 545: 162.36856269879127
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 546: 188.53904491835038
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 547: 160.41067021550492
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 548: 171.57311512264056
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 549: 165.7321779746732
# Landing on (-0.04,-0.00) with velocity = 0.00
# Episode 550: 203.4415511498472
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 551: 152.98049889576302
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 552: 158.70599758716014
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 553: 143.11383978376887
# Landing on (-0.01,-0.01) with velocity = 0.00
# Episode 554: 165.18658098512665
# Landing on (0.03,-0.01) with velocity = -0.00
# Episode 555: 178.22038736384414
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 556: 210.391412977985
# Landing on (-0.04,-0.01) with velocity = -0.00
# Episode 557: 151.65087831762426
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 558: 196.38244973755823
# Landing on (-0.05,-0.00) with velocity = -0.00
# Episode 559: 156.94913848273393
# Landing on (0.06,-0.00) with velocity = -0.00
# Episode 560: 183.52482953432857
# Landing on (0.04,-0.00) with velocity = -0.00
# Episode 561: 178.86803852109972
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 562: 170.47112223431864
# Landing on (0.05,-0.00) with velocity = 0.00
# Episode 563: 170.42953027504302
# Landing on (-0.01,-0.00) with velocity = 0.00
# Episode 564: 149.10463760480332
# Landing on (0.02,-0.01) with velocity = -0.00
# Episode 565: 163.36107853610332
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 566: 187.52799106841326
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 567: 146.98043373379224
# Landing on (0.05,-0.00) with velocity = -0.00
# Episode 568: 178.1263494491888
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 569: 199.90529149397156
# Landing on (0.03,-0.00) with velocity = -0.00
# Episode 570: 179.47468837217193
# Landing on (0.05,-0.00) with velocity = -0.00
# Episode 571: 155.8977390922836
# Landing on (0.01,-0.01) with velocity = -0.00
# Episode 572: 175.52694915408995
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 573: 184.04966615974087
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 574: 200.93382745055996
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 575: 147.99585568417115
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 576: 162.70578013313707
# Landing on (-0.04,-0.01) with velocity = -0.00
# Episode 577: 196.12610696289838
# Landing on (0.01,-0.01) with velocity = -0.00
# Episode 578: 166.48153044737893
# Landing on (-0.02,-0.01) with velocity = -0.00
# Episode 579: 173.55904156790004
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 580: 173.85980860603456
# Landing on (-0.00,-0.00) with velocity = -0.00
# Episode 581: 137.80687375642532
# Landing on (0.04,-0.01) with velocity = -0.00
# Episode 582: 144.43504115778526
# Landing on (-0.06,0.00) with velocity = 0.00
# Episode 583: -383.84080069643136
# Landing on (-0.99,0.12) with velocity = -0.14
# Episode 584: 181.23512117440458
# Landing on (0.06,-0.00) with velocity = 0.00
# Episode 585: 170.88759622881713
# Landing on (0.01,-0.01) with velocity = -0.00
# Episode 586: 164.61131055752247
# Landing on (-0.01,-0.01) with velocity = 0.00
# Episode 587: 166.14635029270963
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 588: 180.13987348997284
# Landing on (-0.01,-0.01) with velocity = -0.00
# Episode 589: 137.25745079596362
# Landing on (0.00,-0.00) with velocity = -0.00
# Episode 590: 158.98320738431582
# Landing on (0.01,-0.01) with velocity = 0.00
# Episode 591: 153.9308944642477
# Landing on (-0.03,-0.01) with velocity = 0.00
# Episode 592: 194.02599149186662
# Landing on (0.06,-0.00) with velocity = -0.00
# Episode 593: 142.58669837110676
# Landing on (-0.03,0.00) with velocity = -0.00
# Episode 594: 174.56268582567594
# Landing on (0.00,-0.00) with velocity = -0.00
# Episode 595: 123.6082386369009
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 596: 141.88462960291596
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 597: 187.63156815342504
# Landing on (0.05,0.00) with velocity = -0.00
# Episode 598: 176.15679131180306
# Landing on (0.05,-0.01) with velocity = 0.00
# Episode 599: 185.21923652385547
# Landing on (-0.02,-0.01) with velocity = -0.00
# Episode 600: 153.03048057125886
# Landing on (-0.01,-0.00) with velocity = 0.00
# Episode 601: 140.77568477959804
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 602: 160.87491005727074
# Landing on (0.05,-0.01) with velocity = -0.00
# Episode 603: 163.07671652614712
# Landing on (0.00,-0.01) with velocity = 0.00
# Episode 604: 163.99586172347367
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 605: 170.64289612520747
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 606: 193.95414460020552
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 607: 180.74353259739516
# Landing on (-0.07,-0.00) with velocity = -0.00
# Episode 608: 190.59675834568168
# Landing on (0.03,-0.01) with velocity = -0.00
# Episode 609: 158.61719065424543
# Landing on (-0.04,0.00) with velocity = -0.00
# Episode 610: 150.97393260455104
# Landing on (-0.03,-0.01) with velocity = -0.00
# Episode 611: 143.91773424590016
# Landing on (0.06,-0.01) with velocity = -0.00
# Episode 612: 141.94547156814065
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 613: 175.5302766577015
# Landing on (0.03,-0.00) with velocity = -0.00
# Episode 614: 159.29308574791457
# Landing on (-0.02,-0.01) with velocity = 0.00
# Episode 615: 183.08240866869414
# Landing on (0.01,-0.01) with velocity = 0.00
# Episode 616: 171.4094021895012
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 617: 206.5708145398482
# Landing on (-0.08,-0.00) with velocity = -0.00
# Episode 618: 169.4355952335095
# ...
# Episode 795: 185.33676124055282
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 796: 186.34017672059298
# Landing on (0.09,-0.00) with velocity = 0.00
# Episode 797: 189.88721551026634
# Landing on (0.05,-0.00) with velocity = 0.00
# Episode 798: 172.2350872721338
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 799: 194.78666245076775
# Landing on (-0.05,-0.00) with velocity = -0.00
# Episode 800: 125.75989628069176
# Landing on (0.35,-0.03) with velocity = 0.00
# Episode 801: 173.39006681160149
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 802: 146.17277470741888
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 803: 166.94498868015967
# Landing on (-0.01,-0.01) with velocity = 0.00
# Episode 804: 170.71659606734642
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 805: 170.75549462211066
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 806: 161.86222780549068
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 807: 197.8664823214235
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 808: 189.7494659420216
# Landing on (0.12,-0.01) with velocity = -0.00
# Episode 809: 168.67634596076428
# Landing on (-0.04,-0.00) with velocity = 0.00
# Episode 810: 188.09538630614176
# Landing on (0.06,-0.00) with velocity = 0.00
# Episode 811: 174.73870944828204
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 812: 147.91371100224856
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 813: 168.69562676023102
# Landing on (-0.00,-0.01) with velocity = 0.00
# Episode 814: 182.27069792680882
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 815: 190.3206177928101
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 816: 159.30073348231028
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 817: 160.53345415538638
# Landing on (-0.01,0.00) with velocity = 0.00
# Episode 818: 173.38034539018383
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 819: 172.66436905336244
# Landing on (0.05,-0.00) with velocity = -0.00
# Episode 820: 194.84713563629074
# Landing on (-0.00,-0.00) with velocity = -0.00
# Episode 821: 134.6195310426911
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 822: 149.42467027547585
# Landing on (0.06,-0.00) with velocity = 0.00
# Episode 823: 188.7743673562445
# Landing on (-0.02,-0.00) with velocity = -0.00
# Episode 824: 179.988835082619
# Landing on (-0.01,-0.01) with velocity = -0.00
# Episode 825: 158.70986618733093
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 826: 159.00349811023398
# Landing on (0.05,-0.00) with velocity = 0.00
# Episode 827: 163.05950841989528
# Landing on (-0.19,0.01) with velocity = 0.00
# Episode 828: 161.97720945789075
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 829: 176.01375580646064
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 830: 159.03232848347145
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 831: 187.57600259946236
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 832: 161.8417894623877
# Landing on (-0.05,-0.00) with velocity = 0.00
# Episode 833: 172.20001533744258
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 834: 145.2393234788684
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 835: 176.49464657436806
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 836: 180.7565941068881
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 837: 144.72488467088885
# Landing on (0.03,-0.00) with velocity = -0.00
# Episode 838: 154.5409129818056
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 839: 144.44032778462451
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 840: 186.62219361261518
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 841: 192.54238503434289
# Landing on (0.05,0.00) with velocity = -0.00
# Episode 842: -206.57004500828106
# Landing on (-1.00,0.03) with velocity = -0.16
# Episode 843: 132.63755336578024
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 844: 194.2046022361161
# Landing on (0.03,-0.01) with velocity = 0.00
# Episode 845: 210.38172119830497
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 846: 177.24975866104197
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 847: 170.5848527503715
# Landing on (-0.04,0.00) with velocity = -0.00
# Episode 848: 199.9286772284084
# Landing on (0.04,-0.01) with velocity = 0.00
# Episode 849: -500.0519035316647
# Landing on (-0.97,0.05) with velocity = -0.26
# Episode 850: 128.69334364312138
# Landing on (0.01,0.00) with velocity = -0.00
# Episode 851: 195.91195842540722
# Landing on (-0.05,-0.01) with velocity = -0.00
# Episode 852: 156.04476111416952
# Landing on (-0.00,-0.00) with velocity = 0.00
# Episode 853: 173.51948731113418
# Landing on (0.04,-0.00) with velocity = -0.00
# Episode 854: 199.28084607752035
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 855: 163.431685003273
# Landing on (-0.00,-0.00) with velocity = 0.00
# Episode 856: 155.3721506544679
# Landing on (0.02,-0.01) with velocity = 0.00
# Episode 857: 169.37281252383758
# Landing on (0.05,-0.00) with velocity = -0.00
# Episode 858: 133.4243340604983
# Landing on (0.00,-0.00) with velocity = -0.00
# Episode 859: 168.10034612417468
# Landing on (0.05,-0.01) with velocity = -0.00
# Episode 860: 155.95897433026292
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 861: 137.63510449402963
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 862: 177.6770529587174
# Landing on (0.01,-0.01) with velocity = 0.00
# Episode 863: 189.21732935332608
# Landing on (0.00,-0.01) with velocity = -0.00
# Episode 864: 186.16199094302215
# Landing on (-0.00,-0.00) with velocity = 0.00
# Episode 865: 178.7223559432433
# Landing on (0.12,0.00) with velocity = -0.00
# Episode 866: 187.24471419433274
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 867: 166.5271652143875
# Landing on (0.01,-0.01) with velocity = -0.00
# Episode 868: 201.1805241826016
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 869: 147.95671102588128
# Landing on (-0.01,-0.00) with velocity = 0.00
# Episode 870: 178.496588619743
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 871: 175.88908714423656
# Landing on (0.04,-0.00) with velocity = -0.00
# Episode 872: 206.8603233263182
# Landing on (-0.05,-0.01) with velocity = 0.00
# Episode 873: 176.38718206628567
# Landing on (0.06,-0.00) with velocity = 0.00
# Episode 874: 170.14028128292293
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 875: 143.35844394208942
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 876: 177.7707948974492
# Landing on (-0.02,-0.00) with velocity = -0.00
# Episode 877: 138.1386830883129
# Landing on (-0.05,-0.00) with velocity = 0.00
# Episode 878: 168.01192252294038
# Landing on (0.01,-0.01) with velocity = 0.00
# Episode 879: 188.62968284891977
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 880: 178.64055987394877
# Landing on (-0.01,-0.00) with velocity = 0.00
# Episode 881: 133.4011707791692
# Landing on (-0.00,-0.00) with velocity = 0.00
# Episode 882: 188.2652393621777
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 883: 176.7928103170951
# Landing on (-0.05,-0.00) with velocity = -0.00
# Episode 884: -219.47963795488468
# Landing on (-0.61,-0.12) with velocity = -0.37
# Episode 885: 137.95349738040093
# Landing on (0.00,-0.00) with velocity = -0.00
# Episode 886: 120.26280451531859
# Landing on (-0.04,-0.00) with velocity = 0.00
# Episode 887: 183.6799039391502
# Landing on (-0.03,-0.00) with velocity = 0.00
# Episode 888: 163.75342845313705
# Landing on (-0.06,-0.01) with velocity = 0.00
# Episode 889: 181.5800532483986
# Landing on (0.03,-0.00) with velocity = -0.00
# Episode 890: 194.16702690200205
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 891: 172.1976391872315
# Landing on (0.04,-0.01) with velocity = -0.00
# Episode 892: 177.01715701868451
# Landing on (0.02,0.00) with velocity = -0.00
# Episode 893: 138.82719795663007
# Landing on (0.01,-0.01) with velocity = 0.00
# Episode 894: 185.31780196274252
# Landing on (-0.07,-0.00) with velocity = -0.00
# Episode 895: 163.63554751948897
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 896: 174.83414517179133
# Landing on (0.04,-0.00) with velocity = -0.00
# Episode 897: 206.11445043536074
# Landing on (-0.04,-0.00) with velocity = 0.00
# Episode 898: 194.3519227090737
# Landing on (-0.11,-0.00) with velocity = -0.00
# Episode 899: 143.78680522901112
# Landing on (0.03,-0.01) with velocity = 0.00
# Episode 900: 151.62522502592628
# Landing on (-0.00,-0.00) with velocity = -0.00
# Episode 901: 156.454487699404
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 902: 181.4819230424109
# Landing on (-0.04,-0.01) with velocity = 0.00
# Episode 903: 183.29832639344912
# Landing on (0.04,-0.00) with velocity = -0.00
# Episode 904: 128.20405400466706
# Landing on (0.07,0.00) with velocity = -0.00
# Episode 905: 140.7967795994456
# Landing on (0.06,-0.00) with velocity = 0.00
# Episode 906: 151.80642513511313
# Landing on (-0.00,-0.00) with velocity = 0.00
# Episode 907: 175.16275962482496
# Landing on (-0.04,-0.00) with velocity = 0.00
# Episode 908: 172.08282598230565
# Landing on (-0.06,-0.00) with velocity = 0.00
# Episode 909: 139.80100553925232
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 910: 98.88029436884759
# Landing on (0.18,-0.00) with velocity = -0.00
# Episode 911: 165.38164603168076
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 912: 171.61006598779093
# Landing on (0.03,-0.00) with velocity = -0.00
# Episode 913: 158.2716426774811
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 914: 177.19823123687632
# Landing on (0.06,-0.00) with velocity = -0.00
# Episode 915: 194.38457376066106
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 916: 193.83475956489295
# Landing on (0.01,-0.01) with velocity = 0.00
# Episode 917: 173.53055272246849
# Landing on (-0.07,-0.00) with velocity = -0.00
# Episode 918: 195.07316026031998
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 919: 199.2298537883118
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 920: 158.07912372792308
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 921: -27.317698620070857
# Landing on (0.37,0.10) with velocity = -0.14
# Episode 922: 116.42775970037397
# Landing on (0.03,-0.00) with velocity = -0.00
# Episode 923: 173.2410158341573
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 924: 171.32788102428364
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 925: 165.36868258039107
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 926: 149.1221383176595
# Landing on (-0.00,-0.00) with velocity = -0.00
# Episode 927: 165.71475102787156
# Landing on (-0.01,-0.00) with velocity = 0.00
# Episode 928: 163.35195362720188
# Landing on (0.03,0.00) with velocity = -0.00
# Episode 929: 183.84572335910204
# Landing on (0.06,-0.00) with velocity = -0.00
# Episode 930: 150.23033922026593
# Landing on (0.05,-0.00) with velocity = 0.00
# Episode 931: 186.56306249857647
# Landing on (-0.07,-0.00) with velocity = 0.00
# Episode 932: 188.91371471535732
# Landing on (0.05,-0.00) with velocity = 0.00
# Episode 933: 156.62481312578203
# Landing on (-0.05,-0.01) with velocity = -0.00
# Episode 934: 149.91409197748854
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 935: 154.79983375771312
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 936: 188.58065990532066
# Landing on (0.04,-0.01) with velocity = 0.00
# Episode 937: 138.06161348841775
# Landing on (-0.01,-0.01) with velocity = -0.00
# Episode 938: 143.6164850720255
# Landing on (-0.02,-0.00) with velocity = -0.00
# Episode 939: 151.3083988158381
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 940: 161.2676182980707
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 941: 180.57390369790625
# Landing on (0.06,-0.00) with velocity = -0.00
# Episode 942: 183.6577581622397
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 943: 184.67180653810905
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 944: 155.629909623848
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 945: 194.26921626968618
# Landing on (0.01,-0.01) with velocity = 0.00
# Episode 946: 188.68636577246065
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 947: 140.54303526434805
# Landing on (0.00,-0.00) with velocity = 0.00
# Episode 948: 161.6036152592448
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 949: 181.18555825621488
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 950: 163.45431129737835
# Landing on (-0.01,-0.00) with velocity = 0.00
# Episode 951: 167.24866649086746
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 952: 169.352708623678
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 953: 172.4997228984252
# Landing on (-0.01,-0.00) with velocity = 0.00
# Episode 954: 153.73897874384863
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 955: 203.7678262820542
# Landing on (-0.05,-0.00) with velocity = 0.00
# Episode 956: 155.4079910161093
# Landing on (0.01,-0.01) with velocity = 0.00
# Episode 957: 204.70071036495585
# Landing on (-0.03,-0.01) with velocity = -0.00
# Episode 958: 128.2273586607001
# Landing on (0.03,0.00) with velocity = -0.00
# Episode 959: 190.17649208633316
# Landing on (0.00,-0.00) with velocity = -0.00
# Episode 960: -119.8844609641478
# Landing on (0.86,0.06) with velocity = -0.12
# Episode 961: 184.5680054639207
# Landing on (-0.06,-0.00) with velocity = -0.00
# Episode 962: 150.69504704725838
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 963: 146.84900248464373
# Landing on (-0.01,-0.01) with velocity = -0.00
# Episode 964: 160.66122285487143
# Landing on (-0.03,-0.01) with velocity = 0.00
# Episode 965: 173.80488336201725
# Landing on (-0.01,-0.01) with velocity = 0.00
# Episode 966: -265.66843809909574
# Landing on (0.99,0.19) with velocity = -0.05
# Episode 967: 155.8716234634675
# Landing on (0.07,-0.00) with velocity = -0.00
# Episode 968: 179.33535254769885
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 969: 178.85306480136873
# Landing on (0.07,-0.00) with velocity = 0.00
# Episode 970: 183.46694726819638
# Landing on (0.01,-0.01) with velocity = -0.00
# Episode 971: 192.4380374991659
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 972: 162.25054377622595
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 973: 192.35303938958256
# Landing on (0.04,-0.00) with velocity = 0.00
# Episode 974: 177.170201620603
# Landing on (-0.02,-0.00) with velocity = -0.00
# Episode 975: 181.47652560073595
# Landing on (-0.05,-0.01) with velocity = 0.00
# Episode 976: 158.61716262649554
# Landing on (0.05,-0.01) with velocity = -0.00
# Episode 977: 181.27795437240667
# Landing on (-0.05,-0.00) with velocity = -0.00
# Episode 978: 158.31284603061496
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 979: 151.89937690084068
# Landing on (-0.01,-0.01) with velocity = 0.00
# Episode 980: 169.87794627891205
# Landing on (-0.03,-0.00) with velocity = -0.00
# Episode 981: 148.52608772757281
# Landing on (-0.06,-0.00) with velocity = -0.00
# Episode 982: 148.6472495705866
# Landing on (0.02,-0.00) with velocity = -0.00
# Episode 983: 161.18121017036617
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 984: 186.5262610056938
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 985: 159.62214587640926
# Landing on (0.00,0.00) with velocity = 0.00
# Episode 986: 175.62193592024227
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 987: 176.39024457367168
# Landing on (-0.01,-0.00) with velocity = -0.00
# Episode 988: 166.1400778541177
# Landing on (0.01,-0.00) with velocity = -0.00
# Episode 989: 165.34228562186013
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 990: 157.4012352195458
# Landing on (-0.01,-0.01) with velocity = -0.00
# Episode 991: 172.87042902772052
# Landing on (0.04,-0.01) with velocity = -0.00
# Episode 992: 177.50702858168106
# Landing on (-0.02,-0.00) with velocity = 0.00
# Episode 993: 182.33788069400663
# Landing on (0.05,-0.00) with velocity = -0.00
# Episode 994: 146.87121300160024
# Landing on (-0.01,0.00) with velocity = -0.00
# Episode 995: 161.68156562182713
# Landing on (-0.05,-0.00) with velocity = 0.00
# Episode 996: 190.85588165980928
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 997: 195.46290498191325
# Landing on (0.03,-0.00) with velocity = 0.00
# Episode 998: 133.69868984877706
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 999: 150.94717529574294
# Landing on (-0.00,-0.00) with velocity = -0.00
#
# Mean Reward over 1000 episode(s): 153.21667011557835

# %%
# Plot: Scores über Episoden
plt.figure(figsize=(12, 6))
plt.plot(range(1, 1001), total_rewards, marker=".", label="Scores")
plt.plot(range(1, 1001), [np.mean(total_rewards[:x]) for x in range(1, 1001)], marker=".", label="Mean Score")
plt.title('Entwicklung des Scores über die Episoden')
plt.legend()
plt.xlabel('Episode')
plt.ylabel('Score')
plt.grid()
plt.show()

# %%
# Plot: Entfernung zu x=0
plt.figure(figsize=(12, 6))
plt.plot(range(1, 1001), err, marker=".", label="X-Cord")
plt.plot(range(1, 1001), [np.mean(err[:x]) for x in range(1, 1001)], marker=".", label="Mean Error")
plt.title('Entwicklung der Landungskoordinaten über die Episoden')
plt.legend()
plt.xlabel('Episode')
plt.ylabel('Abweichung von x=0.0')
plt.grid()
plt.show()

# %% [markdown]
# Hier kann natürlich auch mit dem menschlichen Auge beispielsweise zehn Landungen simuliert und ausgegeben werden.

# %%
# Visualisierung des Lernfortschrittes für die besten Parameter als Mensch
print("\nPlaying with the best parameters...\n")
_,_ = play_with_best_params(best_pid_params, n_episodes=10, render_mode="human")
# Out:
# Playing with the best parameters...
#
# Episode 0: 197.56177108397804
# Landing on (-0.00,-0.00) with velocity = -0.00
# Episode 1: 159.80949974664378
# Landing on (0.06,-0.00) with velocity = -0.00
# Episode 2: 139.97217251365046
# Landing on (0.00,-0.00) with velocity = -0.00
# Episode 3: 169.00857028793808
# Landing on (-0.04,-0.00) with velocity = -0.00
# Episode 4: 163.96407261424287
# Landing on (0.01,-0.00) with velocity = 0.00
# Episode 5: 150.7165467216179
# Landing on (-0.00,-0.00) with velocity = 0.00
# Episode 6: 149.38591942314062
# Landing on (0.00,-0.01) with velocity = 0.00
# Episode 7: 141.56387269080903
# Landing on (0.02,-0.00) with velocity = 0.00
# Episode 8: 177.17802993178393
# Landing on (-0.04,-0.00) with velocity = 0.00
# Episode 9: 152.2843968292419
# Landing on (-0.05,-0.00) with velocity = 0.00
#
# Mean Reward over 10 episode(s): 160.14448518430464

# %% [markdown]
# ## Fazit

# %% [markdown]
# Das Fazit zu diesem Projekt zeigt, dass der Einsatz eines genetischen Algorithmus zur Optimierung der PID-Parameter zwar knapp nicht das gewünschte Ziel von 200 Punkten erreicht hat, dennoch eine bemerkenswerte Leistung erzielt wurde. Die erzielten Scores liegen konstant im Bereich von 150 Punkten, was auf eine robuste Steuerstrategie hinweist, die sich in ihrer Ausführung als besonders konsistent erweist.
#
# Diese Konsistenz ist von großer Bedeutung, da sie beweist, dass der Lander oft sehr nahe an den idealen Bedingungen arbeitet und zuverlässig gut performt, obwohl das absolute Punktziel nicht vollständig erreicht wurde. Solch ein konsistentes Verhalten ist in dynamischen Systemen wertvoll, da es nicht nur die Leistung, sondern auch die Zuverlässigkeit und den sicheren Betrieb des Landers sicherstellt.
